# %% [markdown]
# # <span style="color:#0b486b">SIT 112 - Data Science Concepts - Assignment 2</span>
#
# ---
# Lecturer: Sergiy Shelyag | sergiy.shelyag@deakin.edu.au<br />
#
# School of Information Technology, <br />
# Deakin University, VIC, Australia.
#
# ### <span style="color:#0b486b">Due: 8pm, 20th May 2022 </span>
# ---

# %% [markdown]
# ## <span style="color:#0b486b">Instructions</span>
#
# This notebook has been prepared for you to complete Assignment 2. Some sections have been partially completed  to help you get started. **The total marks for this notebook is 100**.
#
# * Before you start, read the entire notebook carefully to understand what you need to do. You should also refer to the main instructions in *Assignment2_instructions.pdf*  to know what else you need to complete for this assignment as well submission instruction. <br><br>
#
# * Instructions marked with **(D)** and **(HD)** are for students aiming at high grades. They are more involved and can be completed after all other instructions.
#
#
# * For each cell marked with **#YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL**, there will be places where you **must** supply your own codes when instructed. <br><br>
#
# * For each cell marked with **#YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL**, there will be place where you **must** provide your own comment when instructed. <br><br>
#
#
# ### Submission
#
# You are required to submit **five** files: <br><br>
#
# * The source of your solution notebook: **[groupID]_assignment2_solution.ipynb** (you may need to rename it to .txt for the university system to accept it)
# * An exported version of your output: **[groupID]_assignment2_output.html**
# * Three json data files storing tweets collected for the three keywords, named **[groupID]_[w1].json**, **[groupID]_[w2].json**, **[groupID]_[w3].json** where **[w1], [w2], [w3]** are the three keywords you have been provided.
#
#
#
# As you go through this notebook:
#
# * markdown cells marked with **Note** mean description sections.
# * markdown cells marked with **Instruction** mean the instructions given to you to complete the designated section.

# %% [markdown]
# ## <span style="color:#0b486b">Part 1: Crawling and Storing Tweet Data</span>
#
#
# The first part of the assignment examines your skills and knowledge to query tweets and store them in json files. For **each** provided keyword, your tasks are:
#
# * Crawl all tweets which contain this keyword written in English and geocoded within the location, provided for your group.
# * Store the tweets collected into json files.
#
# ***Follow the instructions below to complete your task***.

# %% [markdown]
# **Note**: The following packages will be required for this assignment. If you need to import more packages, you might append them to the end of the following cell.

# %%
#Import packages needed for processing
import re
import json
import xml
import numpy as np
from collections import Counter
from TwitterAPI import TwitterAPI # in case you need to install this package, see practical 6
from sklearn.cluster import KMeans

import requests

# disabling urllib3 warnings
requests.packages.urllib3.disable_warnings()

import matplotlib.pyplot as plt
# %matplotlib inline

#If you need add any additional packages, then add them below

# %% [markdown]
# **Instruction 1.1**. Enter your provided keywords to the variable **keywords** below.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

#Enter the list of three keywords you selected to the variables keywords below
#e.g. keywords = ["abc", "def", "ghi"]

keywords = ["observation", "needle", "income"]

# %% [markdown]
# **Instruction 1.2**. Before you can perform a query to Twitter API, you need to supply authentication information. Practical sessions 6 and 7 show you how to obtain this information. **Your task is to supply the authentication information in the cell below**.
#
# **Note**: You might decide to regenerate this authentication from the pracs if you would like too. <span style="color:red">After the assignment has been marked, you are strongly recommended to regenerate this authentication information from your account to maintain your privacy.</span>
#
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# Twitter API credentials 
CONSUMER_KEY = "NhLxdUp9m758nE4r3NR0YMhwa"
CONSUMER_SECRET =  "MyIpwPYr3kdpa73AfOHupcg8de6bzRdPNfHJ9N4qXKBmYmkUuS"
OAUTH_TOKEN = "1499244362563465216-HonsyCelr95Fjgy04UqcgE1Po4hOK5"
OAUTH_TOKEN_SECRET = "OgWNw3kr6lVw9Wv5ldvaEI2KaxBZpzy6dbUtHys8fJzuI"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAGF2cQEAAAAAlKsPR6NDJkDTq5%2BZ%2BjGiDm2z6Ho%3D08IsxQFZaODJnS4eNgDkwSNzl06cAqThE2PNKodXZH1rA754If"

# Authenticating with your application credentials
api = TwitterAPI(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, api_version='2')

print(api)
# Out:
# <TwitterAPI.TwitterAPI.TwitterAPI object at 0x0000015B31A96760>

# %% [markdown]
# **Note**: As you have learned from the pracical sessions, to perform a query from Twitter API for a particular geo-coded location you need a center point and a radius. The center point is specified by its (latitude,longitute) pair. **The information below has been provided to you to perform the query in the subsequent tasks**.

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# geo coordinations of the desired place
PLACE_LAT = 53.4808
PLACE_LON = -2.2426
DELTA_LAT = 1.0
DELTA_LON = 1.0

# %% [markdown]
# **Instruction 1.3**. For each keyword, you are required to crawl at least **200** tweets (the more the better) using the Twitter API. However, as you have learned from the practical sessions, each query will return a maximum of only **100** tweets. Therefore, subsequent query **must** use the maximum Tweet ID from the previous batch to crawl the next lot.
#
# The following function, called ***retrieve_tweets()***, has been **partially** implemented to automatically download tweets until it reaches the maximum number of tweets needed.
#
# For example, a function call
# ```
# retrieve_tweets(api, 'car', 50, 200, latitude, longitude, delta_lat, delta_lon)
# ```
# will attempt to crawl a total of at least 200 tweets that contains the word 'car' for a location with given latitude, longidude and radius around it. Within each single query, it will attempt to obtain 50 tweets.
#
# **Your task is to walk through this function and enter your own codes where instructed to complete the function**.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
You will be required to insert your own codes to complete this function. 
Walk through this function and enter your own codes where instructed.
'''
def retrieve_tweets(api, keyword, batch_count, total_count, latitude, longitude, delta_lat, delta_lon):
    """
    collects tweets using the Twitter search API
    
    api:         Twitter API instance
    keyword:     search keyword
    batch_count: maximum number of tweets to collect per each request
    total_count: maximum number of tweets in total
    latitude:    latitude of the location centre from where tweets are retrieved
    longitude:   longitude of the location centre from where tweets are retrieved
    delta_lat:   latitude delta (from the location centre) in degrees
    delta_lon:   longitude delta (from the location centre) in degrees
    """

    
    # the collection of tweets to be returned
    tweets_unfiltered = []
    tweets = []
    
    # the number of tweets within a single query
    batch_count = str(batch_count)
    
    '''
    You are required to insert your own code where instructed to perform the first query to Twitter API.
    Hint: revise the practical session on Twitter API on how to perform query to Twitter API.
    '''    
    resp = api.request('tweets/search/recent', {'query': keyword, 
                                     'max_results': batch_count, 
                                     'tweet.fields': {'lang':'en'},      
                                     'place.fields':{
                                     'geo': {
                                     "type": "Feature",
                                     "bbox": [
                                     longitude - delta_lon,
                                     latitude - delta_lat,
                                     longitude + delta_lon,
                                     latitude + delta_lat
                                      ],
                                      "properties": {}
                                      }}})
    

    # check first if there was an error
    if ('errors' in resp.json()):
        errors = resp.json()['title']
        if (errors == 'Invalid Request'):
            print('Too many attempts to load tweets or too many tweets to load.')
            print('You need to wait for a few minutes before accessing Twitter API again or reduce max_results.')
    
    #if ('statuses' in resp.json()):
    tweets_unfiltered += resp
    
    ids = [int(tweet['id']) for tweet in tweets_unfiltered]
    max_id_str = str(min(ids))
    print()
    
    tweets = [tweet for tweet in tweets_unfiltered if (('RT @' not in tweet['text']) & (tweet['lang'] == 'en'))]
    
    
    # loop until as many tweets as total_count is collected
    number_of_tweets = len(tweets)
    
    while number_of_tweets < total_count:

        resp = api.request('tweets/search/recent', {'query': keyword,
                                         'max_results': batch_count,
                                         'until_id': max_id_str,
                                         'tweet.fields': {'lang':'en'},      
                                         'place.fields':{
                                         'geo': {
                                         "type": "Feature",
                                         "bbox": [
                                         longitude - delta_lon,
                                         latitude - delta_lat,
                                         longitude + delta_lon,
                                         latitude + delta_lat
                                         ],
                                         "properties": {}
                                         }}})

            
        tweets_unfiltered += resp
        tweets = [tweet for tweet in tweets_unfiltered if (('RT @' not in tweet['text']) & (tweet['lang'] == 'en'))]
 
        ids = [int(tweet['id']) for tweet in tweets_unfiltered]
        max_id_str = str(min(ids))
            
        number_of_tweets = len(tweets)
        
        print("{} tweets are collected for keyword {}. ".format(number_of_tweets, keyword))
   
    return tweets

# %% [markdown]
# **Instruction 1.4**. After having defined the ***retrieve_tweets()*** function above, you are now ready to use this function to collect your tweets. Your task is to write the code to perform three function calls, each of which corresponds to one keyword. And, you are required to collect at least **200** tweets for each keyword (the more the better).
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Your task is to write the code to perform three function calls, each corresponds to one keyword. 
And, you are required to collect at least 200 tweets for each key word.
'''

# Collecting the tweets for three assigned keywords, 
# Your function call should look like this:  
#      retrieve_tweets(api, keyword, batch_count, total_count, latitude, longitude, delta_lat, delta_lon)

k1_tweets = retrieve_tweets(api, keywords[0], 100, 400, PLACE_LAT, PLACE_LON, DELTA_LAT, DELTA_LON)
k2_tweets = retrieve_tweets(api, keywords[1], 100, 400, PLACE_LAT, PLACE_LON, DELTA_LAT, DELTA_LON)
k3_tweets = retrieve_tweets(api, keywords[2], 100, 400, PLACE_LAT, PLACE_LON, DELTA_LAT, DELTA_LON)

# PLEASE NOTE THAT IF YOU RUN THIS CELL, IT MIGHT TAKE A WHILE TO DOWNLOAD ALL THE TWEETS REQUIRED.
# MAKE SURE THAT YOU WAIT UNTILL THE CELL FINISHES RUNNING.
# Out:
# 90 tweets are collected for keyword observation.
# 142 tweets are collected for keyword observation.
# 192 tweets are collected for keyword observation.
# 246 tweets are collected for keyword observation.
# 291 tweets are collected for keyword observation.
# 346 tweets are collected for keyword observation.
# 392 tweets are collected for keyword observation.
# 440 tweets are collected for keyword observation.
#
# 99 tweets are collected for keyword needle.
# 164 tweets are collected for keyword needle.
# 209 tweets are collected for keyword needle.
# 263 tweets are collected for keyword needle.
# 319 tweets are collected for keyword needle.
# 365 tweets are collected for keyword needle.
# 409 tweets are collected for keyword needle.
#
# 76 tweets are collected for keyword income.
# 110 tweets are collected for keyword income.
# 154 tweets are collected for keyword income.
# 189 tweets are collected for keyword income.
# 242 tweets are collected for keyword income.
# 284 tweets are collected for keyword income.
# 336 tweets are collected for keyword income.
# 384 tweets are collected for keyword income.
# 422 tweets are collected for keyword income.

# %% [markdown]
# **Instruction 1.5**. To verify the downloading process, write your code to print out the number of tweets which has been collected for each keyword.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print the number of tweets have been collected for each keyword
'''
# INSERT YOUR CODE HERE
print(len(k1_tweets))
print(len(k2_tweets))
print(len(k3_tweets))
# Out:
# 440
# 409
# 422

# %% [markdown]
# **Note:** Each tweet is stored in a dictionary where its keywords are fields in the tweet and values are the information of the fields. The cell below print the type of a tweet.

# %%
# Data type of tweets
print(type(k1_tweets[0]))
# Out:
# <class 'dict'>

# %% [markdown]
# **Instruction 1.6**.  To examine what the tweets look like, in the cell below write your code to print out all fields of the first tweet in `k1_tweets` and print out the text of the first tweet collected for each keyword.
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print out all fields of the first tweet
Hint: You might want to use method keys() of the dictionary
'''
# INSERT YOUR CODE HERE
fields_0 = [field for field in k1_tweets[0].keys()]
print(fields_1)




'''
Write your code to print out the text of the first  tweet collected for each keyword.
'''

print("\nThe text of the first tweet for \"{}\":\n".format(keywords[0]))
# INSERT YOUR CODE HERE
text_0 = [text_0 for text_0 in k1_tweets[0].values()]
print(text_0[2])

print("\nThe text of the first tweet for \"{}\":\n".format(keywords[1]))
# INSERT YOUR CODE HERE
text_1 = [text_1 for text_1 in k1_tweets[0].values()]
print(text_1[2])

print('\nThe text of the first tweet for \"{}\":\n'.format(keywords[2]))
# INSERT YOUR CODE HERE
text_2 = [text_2 for text_2 in k1_tweets[0].values()]
print(text_2[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11112/970291963.py in <module>
#       6 # INSERT YOUR CODE HERE
#       7 fields_0 = [field for field in k1_tweets[0].keys()]
# ----> 8 print(fields_1)
#       9
#      10
#
# NameError: name 'fields_1' is not defined

# %% [markdown]
# **Note**. When collecting data from the Internet, such as Twitter, it is important that we store the data collected in an appropriate format for later data analysis task. We have learned that json is a poplular lightweight data format that can be handy to store unstructured data. For example, with NoSQL we can directly query these files in a 'scaling out' fashion. These technologies are representative features of Big Data Analytics.
#
# The following function has been designed for you to save an object which is a list of dictionaries (such as k1_tweets variable) to a json file. **You will need this function for your next task**.

# %%
def save_to_json(obj, filename):
    """
    saves a list of dictionaries into a json file
    
    obj: list of dictionaries
    filename: filename
    """
    with open(filename, 'w') as fp:
        json.dump(obj, fp, indent=4, sort_keys=True)

# %% [markdown]
# **Instruction 1.7**. Use the function ***save_to_json()*** defined above, for each collection of tweets you have crawled for each keyword, save them into a file named **w.json** where **w** is the keyword.
#
# For example, if your keywords are 'w1', 'w2' and 'w3', then your code must generate three file w1.json, w2.json and w3.json. **Important: you must submit these files together with your notebook solution**.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Use the save_to_json() function defined above, for the collection of tweets 
you have crawled for each keyword, save them into a file named w.json where w is the keyword, taken from keywords list.
'''
# saving the tweets in three json files, one for each keyword
#INSERT YOUR CODE HERE
save_to_json(k1_tweets, keywords[0])
save_to_json(k2_tweets, keywords[1])
save_to_json(k3_tweets, keywords[2])

# %% [markdown]
# ###                                     END OF PART 1
# ----

# %% [markdown]
# ## Part 2: Data Analytics
#
# ### NOTE: ONCE YOU LOADED THE TWEETS AND SAVED JSONS, YOU DO NOT NEED TO REDOWNLOAD THE TWEETS. YOU CAN LOAD THEM FROM JSONS IN THE FOLLOWING SECTION.
#
# The second part of this assignment will examine your skills and knowlege in data manipulation and analysis tasks. It includes three main components:
#
# **Part 2A**. For each keyword, you will be required to load the tweets from your saved json files (from Part 1) and filter out all tweets that are too short.
#
# **Part 2B**. Using your knowledge from practical sessions 5, 6 and 7, you will be required to construct the term-by-document matrix for the tweets and to perform visualisation tasks to understand them.
#
# **Part 2C**. You will apply the Kmeans clustering algorithm to cluster your tweets and report the clustering results.
#
# ***Follow the instructions below to complete your assigned tasks***.

# %% [markdown]
# ### Part 2A: Load and Filter Tweets from Files

# %% [markdown]
# **Instruction 2.1**. The following function, named ***read_json_file()***, has been partially implemented to load data from a json file. This function will be used later on to load three json files you have saved from Part 1. Your task is to insert your own code where instructed to complete this function.
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

'''

Insert your own code where instructed to complete this function

'''
import os

current_path = os.path.abspath('')

def read_json_file(filename):

    """

    reads from a json file and saves the result in a list named data

    """

    with open(os.path.join(current_path, filename), 'r') as fp:

        income = json.loads(fp.read())

    i = 0

    tweets = []  # create an empty list

    fp = open(os.path.join(current_path, filename), encoding='utf8')

    tweets = fp.readlines()

    for tweet in tweets:

        print(tweet)
    data = income

    return data

# %% [markdown]
# **Instruction 2.2**. Now use the ***read_json_file()*** function defined above, write three function calls to load data from three json files you have saved from Part 1.
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write three function calls to load data from three json files you have saved from Part 1.
'''

k1_tweets = read_json_file("observation")
k2_tweets = read_json_file("needle")
k3_tweets = read_json_file("income")
# Out:
# [
#
#     {
#
#         "id": "1523492431500816384",
#
#         "lang": "en",
#
#         "text": "just going over my schedule for the upcoming week \nmonday: final student teaching observation/evaluation \ntuesday: certification exam \nwednesday: department meeting\nthursday: certification exam\nfriday: last day of student teaching \nsaturday: graduation \nsunday: alcohol"
#
#     },
#
#     {
#
#         "id": "1523492379424043008",
#
#         "lang": "en",
#
#         "text": "@phoenix909 @cryharderdem @KYSecState There is no MY side remember? The left vs right argument is just an observation. The left owns most media. Including fox. Though recently the right bought CNN, most of the proposed changes haven't gone into effect yet."
#
#     },
#
#     {
#
#         "id": "1523492352634982401",
#
#         "lang": "en",
#
#         "text": "Why do people have to be so damn stupid on this app? I don't care how well Pizza Hut is doing. I made an observation questioning how well Pizza Hut was doing based on the fact that 3 locations within a 60 mile radius closed within the last 2 years and got attacked for it. #Stupid"
#
#     },
#
#     {
#
#         "id": "1523492329155223552",
#
#         "lang": "en",
#
#         "text": "@DrShayPhD Ha! Best observation ever!"
#
#     },
#
#     {
#
#         "id": "1523492121222680578",
#
#         "lang": "en",
#
#         "text": "@anttimatterr hmmm \ud83e\uddd0 incheresting observation here mr anttimatterr"
#
#     },
#
#     {
#
#         "id": "1523492121075863552",
#
#         "lang": "en",
#
#         "text": "Shaun Micallef made an interesting observation during the debacle.\n\nCameras zoomed in on Morrison making him appear imposing, cameras zoomed out from Albo making him seem insignificant. Subliminal, sneaky and typical dirty tricks from Nine Entertainment.\n\n#Sosomeh #LeadersDebate"
#
#     },
#
#     {
#
#         "id": "1523492085248126976",
#
#         "lang": "en",
#
#         "text": "@BisolaRey After a firm cross check and rigorous observation. I FOUND NEITHER SILVER NOR GOLD, NOT EVEN BITCOIN. Just a sprinkle of happiness and undiluted vawulence. I think that's enough for me to want you\u2764\ufe0f"
#
#     },
#
#     {
#
#         "id": "1523492017103269889",
#
#         "lang": "en",
#
#         "text": "At 6:50 PM, waves measured 9.5 ft at 12 sec intervals from 280 deg W. The wave height meets or exceeds 93 percent (25,973/27,641) of records for May and 91 percent (806/878) for May 8. The last observation to exceed that height was 9.8 ft at 7:50 AM on May 8, 2022. https://t.co/UMHapvtxWi"
#
#     },
#
#     {
#
#         "id": "1523492009255743488",
#
#         "lang": "en",
#
#         "text": "@Steve_Dangle Not a question, just an observation as a Lightning fan. Keefe handled that goaltending change brilliantly. Waited until a TV Timeout, when the goalie is already at the bench. He had a talk with him where I assume he told him this isn't on you. Just trying to spark the team."
#
#     },
#
#     {
#
#         "id": "1523491866628718592",
#
#         "lang": "en",
#
#         "text": "@ABillionSuns @johnb78 Ah, yes, won\u2019t play your silly game (which can be summed up by an observation of your profile avatar) so \u2018didn\u2019t get the reference\u2019. \ud83e\udd23 https://t.co/MmzpGXhSJh"
#
#     },
#
#     {
#
#         "id": "1523491832344498179",
#
#         "lang": "en",
#
#         "text": "@JaquelineOutram @Trixie_Boo A very good observation \ud83d\udc4d\ud83d\udc4d\ud83d\ude02\ud83d\ude02\ud83d\ude02, always difficult to look past the white pants suit of Michaela\u2019s."
#
#     },
#
#     {
#
#         "id": "1523491679285956609",
#
#         "lang": "en",
#
#         "text": "@DosMinutos making an observation when shooting 1/5 and having 0 defense is not slandering but go off."
#
#     },
#
#     {
#
#         "id": "1523491678811680768",
#
#         "lang": "en",
#
#         "text": "@DolamiteD Just an observation."
#
#     },
#
#     {
#
#         "id": "1523491611748880384",
#
#         "lang": "en",
#
#         "text": "@MixOnSight @DegenToonz Nice observation \ud83e\udde0\ud83e\udde8\ud83d\ude80 https://t.co/MHzQ79jcQb"
#
#     },
#
#     {
#
#         "id": "1523491524625182720",
#
#         "lang": "en",
#
#         "text": "@Linlinx11 You\u2019re being asked to question whether or not your energy is being misdirected. You have guides that offer their opportunity for insight and observation. You have the chance to reevaluate at any point along your path, it isn\u2019t linear. \ud83e\udde1 https://t.co/AtYqtHCdkG"
#
#     },
#
#     {
#
#         "id": "1523491384988094464",
#
#         "lang": "en",
#
#         "text": "@rexmundictrl @MrAndyNgo Good observation, well done."
#
#     },
#
#     {
#
#         "id": "1523491360677847046",
#
#         "lang": "en",
#
#         "text": "@DylanDoesDucks Could also be them after other fluids besides blood (they all look like females though). This is a really fascinating observation. Could lead to a lot of interesting research avenues."
#
#     },
#
#     {
#
#         "id": "1523491353086201856",
#
#         "lang": "en",
#
#         "text": "@rlj_law @LizSpecht Because people ate mostly meat and whole foods back then.\nCow &amp; goat milk, for people who're tolerant, is a superlative source of nutrients for keeping ones bones healthy. I know from both observation &amp; persnl experience. My vegan friends in their 70s have shrunk 2 - 3 inchs."
#
#     },
#
#     {
#
#         "id": "1523491349873319936",
#
#         "lang": "en",
#
#         "text": "@ASoftstar Yeap very good observation!"
#
#     },
#
#     {
#
#         "id": "1523491284668665857",
#
#         "lang": "en",
#
#         "text": "Another great #IndyCNC #CitizenScience #CityNatureChallenge observation by jillolinger #ItsMyCity #INThisTogether #ScienceSunday\n\nPlease take a moment to fill out our feedback form if you participated!\n\nhttps://t.co/VYlnCVkNGm https://t.co/10zoXRQiqk"
#
#     },
#
#     {
#
#         "id": "1523491265597214720",
#
#         "lang": "en",
#
#         "text": "Is continuing for everything, our observation opens the window of\n\u061f?\n\u0633\u06d2\u0641\u06d2 \u0646\u0645\u0634\u06d2 https://t.co/8pmeOdMIFP"
#
#     },
#
#     {
#
#         "id": "1523491218444890113",
#
#         "lang": "en",
#
#         "text": "i will start episode two with this observation: they gave the PERFECT voice to this whiny reddit gamer bro but it is like nails on a chalkboard to listen to. kudos to both actor and director #tnhsscum"
#
#     },
#
#     {
#
#         "id": "1523491092985188353",
#
#         "lang": "en",
#
#         "text": "#Halalan2022 just an observation, ang konti ng 18-40 y.o. voters dito sa Maligaya Elementary School (North QC) at this time. I\u2019d say around 20% lang. Hope the younger ones vote later. Baka mas wais sila in choosing to go as the queues thin out."
#
#     },
#
#     {
#
#         "id": "1523491076203421696",
#
#         "lang": "en",
#
#         "text": "We are engaged in offering a large range of Clean Room Reverse Laminar Flow. Provided Clean Room Reverse Laminar Flow is made using high-grade components under the observation of our experienced prof ...more\u2026 https://t.co/EBbg7f2iXo #ReverseLaminarFlow #Gujarat"
#
#     },
#
#     {
#
#         "id": "1523491073108062208",
#
#         "lang": "en",
#
#         "text": "@PPdroptheT @della_morte_ I think the \"angry BW\" is a lie of projection from WW and White Supremacy, because from my perspective and observation, there's white rage, there's the problematic and angry white woman...I rarely see a BW acting out in public settings"
#
#     },
#
#     {
#
#         "id": "1523491007387512833",
#
#         "lang": "en",
#
#         "text": "observation: i get the same or better CCV on @Twitch with baggy clothes &amp; no makeup as i do when i\u2019m doing the \u201ce-girl\u201d thing.  u can criticize women all you want for \u201chaving it easier\u201d but i really think do think personality and content speaks for itself \u2728"
#
#     },
#
#     {
#
#         "id": "1523490697759780864",
#
#         "lang": "en",
#
#         "text": "Just... More of an observation of the reaction. https://t.co/vBipIOBux3"
#
#     },
#
#     {
#
#         "id": "1523490664809332736",
#
#         "lang": "en",
#
#         "text": "@HarrisD63432503 @s_shreyatweets @RahulGandhi Most faulty observation."
#
#     },
#
#     {
#
#         "id": "1523490645301637120",
#
#         "lang": "en",
#
#         "text": "@RNFringe My own opinion:\n\nThey are terrified.\n\nEvery lie is falling apart.\n\n\"People\" on both sides are eyeing leadership for \"this\".(whichever \"this\" you reference, many choices at this point\ud83e\udd37\u200d\u2640\ufe0f)\n\nI have nothing but observation to back this up, and I have no speculation as to why \"there\"."
#
#     },
#
#     {
#
#         "id": "1523490625844248576",
#
#         "lang": "en",
#
#         "text": "@iDNAu1 @ghelfaire @LittleVMills Pretty simple observation.\n\nWhere would you even get it?"
#
#     },
#
#     {
#
#         "id": "1523490593120276482",
#
#         "lang": "en",
#
#         "text": "@arbitram @bkjaggi @sridhariyer5 @thekaipullai That will not be a bad observation too about the viewers. Cheers"
#
#     },
#
#     {
#
#         "id": "1523490469858414594",
#
#         "lang": "en",
#
#         "text": "30 min Observation of the Northman movie, yeah it\u2019s racist as fuck ."
#
#     },
#
#     {
#
#         "id": "1523490464501882881",
#
#         "lang": "en",
#
#         "text": "@Malaichamy73 @AnkitIndiaReal Good observation man...How many dmk cadres joined with him.. Even If Tiruchi Siva joins BJP we don't care"
#
#     },
#
#     {
#
#         "id": "1523490448425299973",
#
#         "lang": "en",
#
#         "text": "At 23:30:02 #bgosays A special observation of BGO-899-S4_0954+65 (ID 18911) for Filipp Romanov is starting..."
#
#     },
#
#     {
#
#         "id": "1523490389139034112",
#
#         "lang": "en",
#
#         "text": "Is it me or does it seem like the Dem Party cares way more about transgender people than other \"minorities\"?\n\nObv no disrespect for my trans friends.  This is just an observation."
#
#     },
#
#     {
#
#         "id": "1523490307396243456",
#
#         "lang": "en",
#
#         "text": "@shxtou Through my observation, I found that you like Japanese food very much\uff01"
#
#     },
#
#     {
#
#         "id": "1523490285778784256",
#
#         "lang": "en",
#
#         "text": "I was spot on with this observation \u2705 https://t.co/BWyQWIoztd"
#
#     },
#
#     {
#
#         "id": "1523490260814282753",
#
#         "lang": "en",
#
#         "text": "@catherine___c Many are dissociated from any political observation other than the opinion of; Labor are for the workers, liberal are for millionaires."
#
#     },
#
#     {
#
#         "id": "1523490079234093056",
#
#         "lang": "en",
#
#         "text": "@TSTET2016 @TravisAllen02 Its been my observation that normally only chicks and dudes with little or no balls sit like this (cross legged).  I could be wrong, it's been known to happen a few times."
#
#     },
#
#     {
#
#         "id": "1523489993506795521",
#
#         "lang": "en",
#
#         "text": "Took me 3 hours para makaboto. Observation: the system inside the precinct was was organized than the cluster line outside. There was peace and order. \n\nDaming poll watcher from the candidate of theives. #PHVote #Eleksyon2022"
#
#     },
#
#     {
#
#         "id": "1523489686685368320",
#
#         "lang": "en",
#
#         "text": "It's an observation unlikely to please much of anyone but I think it's accurate"
#
#     },
#
#     {
#
#         "id": "1523489675226533888",
#
#         "lang": "en",
#
#         "text": "@gangatoday1 @FullStackLogan @WitnessCitizen @UAP_LEE I think there has been too much observation and not enough conversation."
#
#     },
#
#     {
#
#         "id": "1523489559757025280",
#
#         "lang": "en",
#
#         "text": "@csl_duke Great observation about the Bucks' defensive adjustments. https://t.co/i43qgVnKe4"
#
#     },
#
#     {
#
#         "id": "1523489549149634561",
#
#         "lang": "en",
#
#         "text": "To interpret that d subject of d 1st observation (about tea) was d cause of d 2nd observation (about transformation) is a case of 'post hoc ergo propter hoc'.\nHaving said this,I feel that d tweet in qn cud hv been better composed to make d distinctness of d 2 observations clearer https://t.co/5d7I1IcCgX"
#
#     },
#
#     {
#
#         "id": "1523489542224850944",
#
#         "lang": "en",
#
#         "text": "Lawsuits: GOP activists in Clark, Washoe seek \u2018meaningful voter observation\u2019 https://t.co/YwwTWxUEzH"
#
#     },
#
#     {
#
#         "id": "1523489297789112320",
#
#         "lang": "en",
#
#         "text": "@ChrisMurphyCT @amandacarpenter Excellent observation! Surely this can be a bipartisan issue and something can be done?!"
#
#     },
#
#     {
#
#         "id": "1523489187202166785",
#
#         "lang": "en",
#
#         "text": "@KrishnChak @Anandi_sanatani @want2expres @EAnjuK @SKAgarw06846698 @sudhakarchopra @rashidkk @s_shreyatweets @Savitritvs @Captsandeep2 @IndiaUnleashed_ @KLB04896179 @amanverm_a @howfunnyismath @advaita_11 Who told you that arrest has to be made as soon as FIR is filed in a rape case ?\nPl quote relevant CrPC sections.\nDon't Quote Court's Observation.\nBoth are different."
#
#     },
#
#     {
#
#         "id": "1523488960491622400",
#
#         "lang": "en",
#
#         "text": "Wow this really pissed some people off and all Kiki was doing was making an observation. Reading comprehension amongst physicians must be at an all time LOW. https://t.co/i7WiqVtE33"
#
#     },
#
#     {
#
#         "id": "1523488837514670081",
#
#         "lang": "en",
#
#         "text": "Just my observation as a Black man, Ukraine is a White people's war with fancy people visiting to check their bank balance, Bono entertaining, which Chef is catering this war anyone know?"
#
#     },
#
#     {
#
#         "id": "1523488831302897664",
#
#         "lang": "en",
#
#         "text": "Brain explains his plan and Pinky points out some fatal flaw or observation which Brain ignores. However, by the end of the episode, Pinky is proven correct. Pinky succeeds in taking over the world in two separate episodes before Brain ruins everything. Who's the real genius? \ud83d\udc00 https://t.co/r3a3eyhTeV"
#
#     },
#
#     {
#
#         "id": "1523488734842277888",
#
#         "lang": "en",
#
#         "text": "@PWSurge Very good observation"
#
#     },
#
#     {
#
#         "id": "1523488670900137984",
#
#         "lang": "en",
#
#         "text": "Ms. Mojack's VERY zooted Karaoke observation.\nSinging wears you out, no wonder they get paid so much! \n\ud83d\ude1d\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23"
#
#     },
#
#     {
#
#         "id": "1523488579975929856",
#
#         "lang": "en",
#
#         "text": "My only (and spoiler free) #DrStrangeMultiverseOfMadness observation is that is has my favorite magic duel since Vincent Price &amp; Boris Karloff in The Raven\n#DoctorStrange"
#
#     },
#
#     {
#
#         "id": "1523488449084329984",
#
#         "lang": "en",
#
#         "text": "@AndreBJones2 @tiffanie_tx @DaveSylvester11 How?\nBy who?\nBy people who would protest outside of a supreme court justice on a moments notice?\nBy people who cover observation windows?"
#
#     },
#
#     {
#
#         "id": "1523488406617001985",
#
#         "lang": "en",
#
#         "text": "@rank_matthew @KaskaJessica @protransfemnst It's all theories or a conclusion people have come to based on human observation, research and a hypothesis, usually followed by testing. It also has the potential of being biased &amp; skewed, which happens a lot to minorities. As said, science is not about definitive truths either."
#
#     },
#
#     {
#
#         "id": "1523488278422319105",
#
#         "lang": "en",
#
#         "text": "@Sharky_vs_Evil @PattyCa18904386 @APFactCheck First of all, I was talking about my friends. My observation is based on real people I know. No where did I claimed I had official data so I am not wrong. Second, show me the source of your ridiculous claim. I'll be the judge for myself if the source is credible."
#
#     },
#
#     {
#
#         "id": "1523488199691358209",
#
#         "lang": "en",
#
#         "text": "@FUTUREXKlNG \"No, but as I said. It was based upon your interactions with me. To be rather straightforward. You seem rather soft around me, especially in moments where your face gets all cherry like.\" \n\nThe oblivious man pointed out an observation, without any context."
#
#     },
#
#     {
#
#         "id": "1523488179000864771",
#
#         "lang": "en",
#
#         "text": "@GeorgeTakei Good observation"
#
#     },
#
#     {
#
#         "id": "1523488005662597120",
#
#         "lang": "en",
#
#         "text": "The element most overlook when factoring\nin war, is who has the will?\n\nIt is my observation, that the great divide\namongst people is found in the answer to \nthat question."
#
#     },
#
#     {
#
#         "id": "1523487990072283136",
#
#         "lang": "en",
#
#         "text": "@lomas_scot @VicGovDH Ditto. And my observation is there's no obvious Term 2 spike, but a continuation of a longer trend."
#
#     },
#
#     {
#
#         "id": "1523487969222721536",
#
#         "lang": "en",
#
#         "text": "@sentdefender Sad excuse of a charade to deflect observation away from whats really happening, which is russian forces getting smashed in kherson and elsewhere in the east of ukraine"
#
#     },
#
#     {
#
#         "id": "1523487713340518400",
#
#         "lang": "en",
#
#         "text": "@AnthonyBourque4 @bryanstanf Mandates \ud83d\ude37dropped  here quickly in the NY region &amp; other blue states.. the Dems must have saw the polling. \ud83d\ude44 Now even in my blue town that voted 75% Biden \ud83d\ude44very few people wear masks from my observation .. It\u2019s  over generally over ., Thank God"
#
#     },
#
#     {
#
#         "id": "1523487652846063616",
#
#         "lang": "en",
#
#         "text": "@NeverForgetUA_ @3PeasInALily @DixonCox12 @Lilo___andPeggy @EarlGrayTrekkie I wrote earlier Barclay had a permanent desk assignment, twt vanished, besides, a neurotic but misunderstood herp storyline works an episode a season.\nStd is more like a twisted Love Boat, that's my observation, it's all oddball romance."
#
#     },
#
#     {
#
#         "id": "1523487623729229826",
#
#         "lang": "en",
#
#         "text": "@Cryptocito Gap on CME at 24.8 be aware if we break 32 &amp; change. Just an observation"
#
#     },
#
#     {
#
#         "id": "1523487570088275968",
#
#         "lang": "en",
#
#         "text": "@shallzzz Though it's subjective thing yet   empirical perception is very much close to ur observation since some persons' vibes are comforting beyond words  when in a soup and impedance on so many fronts. The degree of exp.may vary but all fair hearts are on the same page."
#
#     },
#
#     {
#
#         "id": "1523487506167119872",
#
#         "lang": "en",
#
#         "text": "At 23:18:21 #bgosays I have taken a special observation of BGO-899-S5-1803+78 (ID 18909) for Filipp Romanov."
#
#     },
#
#     {
#
#         "id": "1523487218593308673",
#
#         "lang": "en",
#
#         "text": "@davemeltzerWON Great observation from the wrestling observer"
#
#     },
#
#     {
#
#         "id": "1523487215892185088",
#
#         "lang": "en",
#
#         "text": "@DammitBits LOL, no. It's just an observation of what that says about Twitter and it's community really..."
#
#     },
#
#     {
#
#         "id": "1523487207339610112",
#
#         "lang": "en",
#
#         "text": "@Devbino__ good observation Sherlock"
#
#     },
#
#     {
#
#         "id": "1523487149622198272",
#
#         "lang": "en",
#
#         "text": "@swanblack404  @CarolineCoramUK \n\nYour thoughts please:-\n\nAn observation by @TurnOffYourTvN1 \"It's strange how we can't see the sun for the white stuff, which must still be lingering at night yet the moon shines perfectly clear through it.\""
#
#     },
#
#     {
#
#         "id": "1523487059251367937",
#
#         "lang": "en",
#
#         "text": "Just another day in the Jung household. \n\ud83d\udc30: Whoah, it's raining cats and dogs outside.\n\ud83d\udc3b: *Without even raising his head* Astounding observation. I wouldn't have known if you hadn't pointed it out.\n\ud83d\udc30: Hehe, sorry, looks like we're cooped up here for the time being."
#
#     },
#
#     {
#
#         "id": "1523486954045665280",
#
#         "lang": "en",
#
#         "text": "Valid point. Some things are seen in a broader perspective if we have years of observation. https://t.co/5MnMaTcEpv"
#
#     },
#
#     {
#
#         "id": "1523486924874215425",
#
#         "lang": "en",
#
#         "text": "@GeorgeTakei EXCELLENT observation!  I hope that point is brought to their consciousness."
#
#     },
#
#     {
#
#         "id": "1523486923922173954",
#
#         "lang": "en",
#
#         "text": "Nothing against the OP obviously, just an observation. Feel like it\u2019s something that needs to be worked on in the community in general and something even I\u2019ve found myself guilty of."
#
#     },
#
#     {
#
#         "id": "1523486901918846983",
#
#         "lang": "en",
#
#         "text": "No its just an observation. She does needs fashion advice. Could do better . I think the person with short hair ( does the money stuff and fills in ) dresses very well . She\u2019s also quite engaging. She should take Liza shopping.... just a suggestion ."
#
#     },
#
#     {
#
#         "id": "1523486874815242240",
#
#         "lang": "en",
#
#         "text": "@DerpSwan @Aca_Acesome I think and this is just my observation,  that she didnt want to be mean so left it at that. We know she isnt happy it was left out."
#
#     },
#
#     {
#
#         "id": "1523486837217452032",
#
#         "lang": "en",
#
#         "text": "@Strawprincess @Pelon @DiamondLynne1 \ud83d\ude02 great observation! He's mine! \ud83e\udd23"
#
#     },
#
#     {
#
#         "id": "1523486663040987137",
#
#         "lang": "en",
#
#         "text": "@ajamubaraka That's a good and realistic observation \ud83d\udc4d."
#
#     },
#
#     {
#
#         "id": "1523486526679633923",
#
#         "lang": "en",
#
#         "text": "@RichardAkinola @ESPNRingside @DAZNBoxing Good observation! Hope someone asks him."
#
#     },
#
#     {
#
#         "id": "1523486426259591168",
#
#         "lang": "en",
#
#         "text": "I was wondering the same thing. I was also wondering about which leader has ever flown to country while it\u2019s literally a war zone \ud83e\udd14 Great observation tho. https://t.co/5i6vq1x0R6"
#
#     },
#
#     {
#
#         "id": "1523486396455190528",
#
#         "lang": "en",
#
#         "text": "@elonmusk \nBefore that you need a Balance Work\nSet right Twitter How ?\nThose are Paying to Twitter give them 2 Blue Tick\nThose are Real Condidate give them 1 Yellow tick\nThose are fake put them Observation\nLater on Suspend\n@manishm \nJust Do It\n\nThen Globe Going to Universal https://t.co/5HQxIL3Udr"
#
#     },
#
#     {
#
#         "id": "1523486243236966400",
#
#         "lang": "en",
#
#         "text": "#EveshamWeather Observation @ 03:13 - Temp: 10.3\u00b0c, Wind: 0.0 gusting to 0.4 kph,  Pressure: 1026.6, Rain: 0.0mm/h now with 0.0mm today"
#
#     },
#
#     {
#
#         "id": "1523486156088037376",
#
#         "lang": "en",
#
#         "text": "@TaylorRMarshall Just an observation, and not disagreeing with this stance, but the question came into my head: if Traditionalists find the current Pope so terrible, why do they seem to hang on every word that he utters? I mean instead of scrutinizing every action of the Vatican, why not move on"
#
#     },
#
#     {
#
#         "id": "1523486102195163142",
#
#         "lang": "en",
#
#         "text": "$ARKK\n\nJust an observation here but since topping out ARKK has taken out 6 downside vpocs on the daily chart. Friday marks vpoc number 7\n\nEvery takeout has seen a rally back towards the 20ema...will this time be different? https://t.co/h0zjMENP04"
#
#     },
#
#     {
#
#         "id": "1523486001758232577",
#
#         "lang": "en",
#
#         "text": "@Rynge_ Good vibes all round. Again, your observation skills are on point!! \ud83d\udc4c\ud83d\udc4c"
#
#     },
#
#     {
#
#         "id": "1523485936495251456",
#
#         "lang": "en",
#
#         "text": "I\u2019ve noticed since Covid, Trump, whatever, that people seem to be empowered to be assholes. Just in general. Just an observation. So to all those that treated their moms to a nice Mother\u2019s Day feast and then cheaply tipped their servers who gave up their time with"
#
#     },
#
#     {
#
#         "id": "1523485909097742337",
#
#         "lang": "en",
#
#         "text": "@aowdiMG Good observation to read at 7am in morning...."
#
#     },
#
#     {
#
#         "id": "1523485900381982722",
#
#         "lang": "en",
#
#         "text": "My #MondayMotivation is 'nature observation ,what nature itself can teach us ,no other way can do.\nDoing meditation in green garden impulses positive energy within us .\nTeachings by st. @Gurmeetramrahim ji \n@DSSNewsUpdates https://t.co/cKtSaITow7"
#
#     },
#
#     {
#
#         "id": "1523485841749815298",
#
#         "lang": "en",
#
#         "text": "All perceiving is also thinking, all reasoning is also intuition, all observation is also invention."
#
#     },
#
#     {
#
#         "id": "1523485783784525824",
#
#         "lang": "en",
#
#         "text": "@davidjrousseau @marceelias Bipartisan observation is fine. THESE PEOPLE ARE NOT CERTIFIED AND WILL BE IN BREACH OF VOTING REGULATIONS@! THEY ARE REPPUBLICANS NOT BIPARTISAN! AND OUR VOTING SYSTEM IS SAFE, SECURE AND NEVER A PROBLEM UNTIL 2020 WHEN DUMPY LOST! You lose baby boy. Move along now"
#
#     },
#
#     {
#
#         "id": "1523485723877289984",
#
#         "lang": "en",
#
#         "text": "@elevenobi Keen observation"
#
#     },
#
#     {
#
#         "id": "1523485608580042752",
#
#         "lang": "en",
#
#         "text": "Of all the things I imagined doing when I was trying to get a girlfriend, the last one was \u201chelping her pluck ingrown hairs from her pussy\u201d, and that\u2019s not a complaint, just an observation.\nI fucking love her man."
#
#     },
#
#     {
#
#         "id": "1523485322600157184",
#
#         "lang": "en",
#
#         "text": "-- ppearance of Rias' brother, Sirzechs Lucifer, who came for Rias' class observation, telling Rias that Azazel won't do any drastic --"
#
#     },
#
#     {
#
#         "id": "1523485210050166784",
#
#         "lang": "en",
#
#         "text": "@sweetshark @DonaldJTrumpJr You mean like the lowlife who called another man\u2019s wife ugly &amp; his father an assassin?The lowlife who mocked a handicapped reporter? I made a legitimate observation. Jr. sets the example of being a bully, his kids reflect being around that mentality.Your hypocrisy is staggering"
#
#     },
#
#     {
#
#         "id": "1523484676412780545",
#
#         "lang": "en",
#
#         "text": "@0detteroulette @KirstenPowers Glad you sensed a need to insert the \"you fool\" part, or I might have taken your comment for one intending an actual serious adult conversation--that, even though, my comment was/is a broad observation of @KirstenPowers and others in both tribes' *approach*, not the issue itself."
#
#     },
#
#     {
#
#         "id": "1523484647941808128",
#
#         "lang": "en",
#
#         "text": "@VTribbean A correct observation or perhaps it's you exclaiming your thoughts of the tweet and/or picture"
#
#     },
#
#     {
#
#         "id": "1523484639075368963",
#
#         "lang": "en",
#
#         "text": "@shipwreckedcrew Analysis rather than observation. A great race, no doubt. A great horse, obviously - even if only on that day. A great jockey, for sure, in those minutes, unbelievably tuned. Sometimes moments are just that. Enjoy them. It was a special race."
#
#     },
#
#     {
#
#         "id": "1523484540282413057",
#
#         "lang": "en",
#
#         "text": "@CanAm_Indy @RealOmarNavarro He doesn't have to know them. He's also a savvy business man, he will not do stupid things to his new company. To make such an observation, you sound naive."
#
#     },
#
#     {
#
#         "id": "1523484520678588416",
#
#         "lang": "en",
#
#         "text": "@SamKapo44885349 Just making an observation"
#
#     },
#
#     {
#
#         "id": "1523484507814662145",
#
#         "lang": "en",
#
#         "text": "@avarwallace You\u2019re not crazy: noted Philadelphia native John Gonzalez made the same observation."
#
#     },
#
#     {
#
#         "id": "1523484466081333250",
#
#         "lang": "en",
#
#         "text": "@IamTheHuntsman @SlackDragon101 @unfreshprince @The_MJF I made an observation that whyte people have privilege period if you wanna say a black man pointed out something obvious is racist so be it yall make racist remarks every and double down and try to justify why I simply pointed the obvious which os true #factsoverfeelings"
#
#     },
#
#     {
#
#         "id": "1523484372544135168",
#
#         "lang": "en",
#
#         "text": "@KatieRocs It just amazes me how we were taught so much about the rest of the world and America seems to be mostly taught about America .. n even thats debateable. As ever tho .. not all Americans. Just an observation \ud83d\udc9a"
#
#     },
#
#     {
#
#         "id": "1523484223557959680",
#
#         "lang": "en",
#
#         "text": "@LauraSavino747 Your observation is valid: people suck"
#
#     },
#
#     {
#
#         "id": "1523484215056101377",
#
#         "lang": "en",
#
#         "text": "Observation dick reporting in from the observation deck"
#
#     },
#
#     {
#
#         "id": "1523484036035153920",
#
#         "lang": "en",
#
#         "text": "The \"valuable asset\" he had been storing in the observation tower...\nwas, of all fucking things, the girl we'd looked after a few years back--\nMorgana."
#
#     },
#
#     {
#
#         "id": "1523483994066620417",
#
#         "lang": "en",
#
#         "text": "@FakeAnnunziata @Patshala3 @thevivafrei @rumblevideo @DineshDSouza I dont buy their video analysis. They haven't done a good job coming to valid conclusions even when they're using hard data. The conclusions about masks/gloves were not based on measured observation. People who saw some video thought they saw some patterns. Who knows."
#
#     },
#
#     {
#
#         "id": "1523483991956881408",
#
#         "lang": "en",
#
#         "text": "@dolfijnmanjohns Thats a very reductive observation"
#
#     },
#
#     {
#
#         "id": "1523483923099308032",
#
#         "lang": "en",
#
#         "text": "@TakeanPhoenix That\u2019s been my observation as well."
#
#     },
#
#     {
#
#         "id": "1523483850332340224",
#
#         "lang": "en",
#
#         "text": "Dhoni what an inspiration you are! Your undying spirit, strong determination, keen observation &amp; stupendous management skill- it seems you are outdoing yourself only. \n\nYou were, are &amp; will be my emotion forever \ud83d\udc9b\ud83d\udc9b\ud83d\udc9b\n\n#MSDhoni\ud80c\udcf5 #Dhonism #Yellove #CSKvsDC https://t.co/TpVE8KT8b8"
#
#     },
#
#     {
#
#         "id": "1523483811157213185",
#
#         "lang": "en",
#
#         "text": "$naleph from @aleph_finance  is flying under the radar. It seems nobody but the kingship WLers know about it yet. Just 4 buys last 24 hours. Launched a couple days ago.\n\nI am not an investor yet. I was not paid to post this. Just my observation of a quality project w/ a good team https://t.co/fWCXF92SxJ"
#
#     },
#
#     {
#
#         "id": "1523483450958696449",
#
#         "lang": "en",
#
#         "text": "@SketchyToasty Yeah. Redpilled doesn't refer to any political opinion. Merely the observation of a reality hidden from or ignored by the majority. See the 1999 movie The Matrix for reference (choosing the red or blue pill)"
#
#     },
#
#     {
#
#         "id": "1523483432441249793",
#
#         "lang": "en",
#
#         "text": "@PixelBushYT She looks like she spends afternoons signing https://t.co/Y4MAmXL183 petitions\n\nNot negative or positive just an observation"
#
#     },
#
#     {
#
#         "id": "1523483254233333760",
#
#         "lang": "en",
#
#         "text": "Current Observation:\nTemp: 77.7F \nHumidity: 84%\nWind:  94\u00b0 at 0.2 MPH gusting to 1.1\nRain today: 0.0 IN"
#
#     },
#
#     {
#
#         "id": "1523483130622930944",
#
#         "lang": "en",
#
#         "text": "This is the best observation yet. https://t.co/KI1Jmua1fN"
#
#     },
#
#     {
#
#         "id": "1523482939908009984",
#
#         "lang": "en",
#
#         "text": "just a general observation on the leos i know as well as myself bc it's very mindboggling"
#
#     },
#
#     {
#
#         "id": "1523482855476985857",
#
#         "lang": "en",
#
#         "text": "Current Observation:\nTemp: 10.8C \nHumidity: 88%\nWind:  168\u00b0 at 7.2 KPH gusting to 13.0\nRain today: 0.0 MM"
#
#     },
#
#     {
#
#         "id": "1523482844584038400",
#
#         "lang": "en",
#
#         "text": "Current Observation:\nTemp: 78.4F \nHumidity: 13%\nWind:  223\u00b0 at 8.1 MPH gusting to 10.3\nRain today: 0.0 IN"
#
#     },
#
#     {
#
#         "id": "1523482731497230336",
#
#         "lang": "en",
#
#         "text": "Current Observation at Eagleville, PA:\nTemp: 52.5F \nHumidity: 48%\nWind:  2\u00b0 at 1.3 MPH gusting to 3.1\nRain today: 0.0 IN\n\nStation data at https://t.co/8DB5F357oc"
#
#     },
#
#     {
#
#         "id": "1523482601964859392",
#
#         "lang": "en",
#
#         "text": "Google results were fruitless, but this seems like a week-of-release, Entertainment Weekly observation, not a delicate insight plucked twenty years later off the vine by some idiot watching a muted basketball game.\n\nhttps://t.co/HQnGiJ8k84"
#
#     },
#
#     {
#
#         "id": "1523482565339877376",
#
#         "lang": "en",
#
#         "text": "@JudeThaddean The retail, the dining options, the quality of the space\u2026.it\u2019s just super dated and overcrowded and an awful place to spend any time. Makes a zip up 130 seem like a no brainer, especially given the AUS dining, music, observation deck, ceiling height even."
#
#     },
#
#     {
#
#         "id": "1523482556376657922",
#
#         "lang": "en",
#
#         "text": "If I wanted to post black material of wang yibo I will start with his interviews recently. But I don't care I only care how his eyes look apathetic and angry. That's my observation why should I be drag by fans, I see what I see. Don't go here barking."
#
#     },
#
#     {
#
#         "id": "1523482504824385536",
#
#         "lang": "en",
#
#         "text": "A great observation. #auspol https://t.co/XIv6W9CtmU"
#
#     },
#
#     {
#
#         "id": "1523482496998211585",
#
#         "lang": "en",
#
#         "text": "@TypicalJAnt @r1OP3 I'll take this and raise you that Breath of All Things is a mix of Ryuo and Observation Haki"
#
#     },
#
#     {
#
#         "id": "1523482372435746816",
#
#         "lang": "en",
#
#         "text": "@dailwolbit very nice observation omg \ud83d\udc40 so hwanwoong must know something more \ud83e\udd14"
#
#     },
#
#     {
#
#         "id": "1523482171918352384",
#
#         "lang": "en",
#
#         "text": "my relatives chastise me about telling them that they were abusive to others, they tell me I am the bad one because I tell them they are not all pure, they forget history, they forget my observation through time, knowing their deceit of long gone days, I will not remain silent"
#
#     },
#
#     {
#
#         "id": "1523482056092569600",
#
#         "lang": "en",
#
#         "text": "@NumberOneFred My Christian faith. \nAnd  the observation that liberalism does not work at all."
#
#     },
#
#     {
#
#         "id": "1523482045975916544",
#
#         "lang": "en",
#
#         "text": "@ChanderBhatia01 $BRK is one of the best examples of this observation. Lags the market  for a few years and then boom... it is a destination for everyone who wants to preserve capital."
#
#     },
#
#     {
#
#         "id": "1523481841340092416",
#
#         "lang": "en",
#
#         "text": "@GamDave1 It is just wano\u2019s word for haki. Same as mantra from observation. But it\u2019s easier to refer to that adavanced level Luffy learned. If I say \u201cryou\u201d you know what to think of instead of me saying \u201clevel x y or z\u201d haki"
#
#     },
#
#     {
#
#         "id": "1523481791037812737",
#
#         "lang": "en",
#
#         "text": "@Votto007 I\u2019m really not seeing the disproportionality between men treating attractive women better vs women treating attractive men better that warrants this observation. Are you interested in being more convincing about this point?"
#
#     },
#
#     {
#
#         "id": "1523481712453308416",
#
#         "lang": "en",
#
#         "text": "@Most @netflix Hi! Just a little observation: any post about #Heartstopper gets like 10X more impressions than anything else you and your accounts post. Perhaps that is the best sign you have a hit on your hands! Don't fuck it up and just #RENEWHEARTSTOPPER"
#
#     },
#
#     {
#
#         "id": "1523481701451968513",
#
#         "lang": "en",
#
#         "text": "@dj_backyard Odo you are selective that\u2019s all \u2026other people say sensible things but you shut them up . I\u2019m not being emotional just stating an observation \ud83d\ude02\ud83d\ude02"
#
#     },
#
#     {
#
#         "id": "1523481555519246336",
#
#         "lang": "en",
#
#         "text": "An interesting observation from this game: #GoBolts scored seven goals, but did not have one player with more than two points"
#
#     },
#
#     {
#
#         "id": "1523481498099548166",
#
#         "lang": "en",
#
#         "text": "At 22:54:28 #bgosays A special observation of BGO-899-S5-1803+78 (ID 18909) for Filipp Romanov is starting..."
#
#     },
#
#     {
#
#         "id": "1523481420252934144",
#
#         "lang": "en",
#
#         "text": "@KhadzRangwala Good observation \ud83d\ude01\ud83d\ude01"
#
#     },
#
#     {
#
#         "id": "1523481255555178496",
#
#         "lang": "en",
#
#         "text": "@halleberry called deeds of compassion, by observation by God's Own Judgement of never bantering one's own opinion of personal live, of perspectives of others, God Is Never Pleased by that heretical harmful behavior, - God Is Being Forever Sole Judge of waters springing forth to everlasting,"
#
#     },
#
#     {
#
#         "id": "1523481173598474241",
#
#         "lang": "en",
#
#         "text": "It's observation"
#
#     },
#
#     {
#
#         "id": "1523481082410061825",
#
#         "lang": "en",
#
#         "text": "Just an observation: Spo essentially going 7 deep (Vincent 3 fouls in 3 min), with no minutes for Martin, Robinson, or Morris. I\u2019ve learned before he knows way more than me but I am curious."
#
#     },
#
#     {
#
#         "id": "1523481044162588672",
#
#         "lang": "en",
#
#         "text": "@MacDre619 @zigzagswag @Thisanambragirl i\u2019m not sold. it doesn\u2019t sound like a clear stance. more like an observation"
#
#     },
#
#     {
#
#         "id": "1523480982439211008",
#
#         "lang": "en",
#
#         "text": "@etiennefd Um, yes. From simple observation, as others have said: wax burns, but it burns most easily when it is liquid, so the wick is a way to corral the wax for continuous burning, running through the centre and melting/burning down the stack of wax."
#
#     },
#
#     {
#
#         "id": "1523480869054595072",
#
#         "lang": "en",
#
#         "text": "new idea warfare idea dropped (#3-4 for the manual): Quantum observation of humor. All other context equal, knowledge of who makes a joke pre-determines the perceived humor and context"
#
#     },
#
#     {
#
#         "id": "1523480864151113728",
#
#         "lang": "en",
#
#         "text": "@iamtheonlysara It\u2019s pricier, and the longer the distance the more the percentage increase in cost goes up; but I straight up would not be traveling at all otherwise. observation car crowd aside, it\u2019s been a relaxed, enjoyable experience! and very beautiful, the landscape is so beautiful"
#
#     },
#
#     {
#
#         "id": "1523480803899936768",
#
#         "lang": "en",
#
#         "text": "@yooleslieee just my observation \ud83d\udc40"
#
#     },
#
#     {
#
#         "id": "1523480792877330432",
#
#         "lang": "en",
#
#         "text": "Scary stuff\n\nAnalysis/observation  seems right on\n\nI hope his conclusion is correct https://t.co/BYNfKS5jKa"
#
#     },
#
#     {
#
#         "id": "1523480348994138112",
#
#         "lang": "en",
#
#         "text": "@RBReich Astute observation."
#
#     },
#
#     {
#
#         "id": "1523480291872239616",
#
#         "lang": "en",
#
#         "text": "@kelly_ques 107th observation floor on the World Trade Center, New York 1984.  \nNow that I just wrote this. How strange that it was (1984)."
#
#     },
#
#     {
#
#         "id": "1523480188331642880",
#
#         "lang": "en",
#
#         "text": "@shabbirahmadc18 Reham Khan\u2019s observation is valid &amp; concurred. IK is involved in anti state propaganda. He is taking the nation on collision course. Pak Army Zindabad, Pak Paindabad"
#
#     },
#
#     {
#
#         "id": "1523480165212250113",
#
#         "lang": "en",
#
#         "text": "@Nawaaban Observation especially in formative years and essentially from immediate family"
#
#     },
#
#     {
#
#         "id": "1523480136997216256",
#
#         "lang": "en",
#
#         "text": "nobody is entitled to anything nobody is inherently worth anything it is your own actions that give you any worthiness of preservation and observation but solely in the moment. What is a man? A miserable pile of secrets. But enough talk, have at you! https://t.co/Cn5j60s7Ct"
#
#     },
#
#     {
#
#         "id": "1523480126201098240",
#
#         "lang": "en",
#
#         "text": "@Tribe_XX @OurCLEGuardians Hahahaha. An inocuous little observation is now, \"pimping\". YOU\"RE rich."
#
#     },
#
#     {
#
#         "id": "1523480076502769664",
#
#         "lang": "en",
#
#         "text": "The youth has the opportunity to exercise their right t vote and be accountable for who they voted for. It's not some observation from the media anymore. This is the time to immerse yourself in the country you've been waiting to build a future for. Vote wisely\ud83c\udf38"
#
#     },
#
#     {
#
#         "id": "1523480074980184064",
#
#         "lang": "en",
#
#         "text": "Was watching King of the Hill and @OrionSpaceRacc made an important observation https://t.co/Zsr2nm2ssZ"
#
#     },
#
#     {
#
#         "id": "1523479829584433152",
#
#         "lang": "en",
#
#         "text": "At 22:47:50 #bgosays I have taken a special observation of V1117HER (ID 18908) for Filipp Romanov."
#
#     },
#
#     {
#
#         "id": "1523479699644907521",
#
#         "lang": "en",
#
#         "text": "@gnanilab I love this observation so much Sumi. \ud83d\ude02\ud83e\udee3"
#
#     },
#
#     {
#
#         "id": "1523479650789253121",
#
#         "lang": "en",
#
#         "text": "Who am I, living in the middle of history, to tell the universe that it-or my observation of it-is temporary?'"
#
#     },
#
#     {
#
#         "id": "1523479595588022278",
#
#         "lang": "en",
#
#         "text": "@IWtfdidtweet @elonmusk @WholeMarsBlog It's called an observation. Get a dictionary"
#
#     },
#
#     {
#
#         "id": "1523479593952628736",
#
#         "lang": "en",
#
#         "text": "based on my observation palang 'to ha, di pa ko nakakaboto eh mamaya palang pero I noticed how the machine always allegedly breaks, when majority of the voters atm are YOUTH. these people na nadaan sa pera-pera knows their target demographic and that is the youth."
#
#     },
#
#     {
#
#         "id": "1523479556417417219",
#
#         "lang": "en",
#
#         "text": "An observation about David Speers: \u2018you can take the man out of Sky, but you cannot take the Sky out of the man\u2019 - Tim Jones.   Agreed"
#
#     },
#
#     {
#
#         "id": "1523479549132292097",
#
#         "lang": "en",
#
#         "text": "3 Main Points Of Driving * Concentration, Observation, Anticipation * Taught Here\n\nAmazon * https://t.co/3grID8C6z9 - Right hand side of road\nAmazon * https://t.co/4rBAI7uvcX - Left hand side\n\nBoth 5star #RoadSafety books available at all worldwide Amazon sites https://t.co/RtkLQIIQ03"
#
#     },
#
#     {
#
#         "id": "1523479546745421828",
#
#         "lang": "en",
#
#         "text": "@P_mathers I knew what ya meant \ud83d\udc4d and very good observation"
#
#     },
#
#     {
#
#         "id": "1523479544534945793",
#
#         "lang": "en",
#
#         "text": "@SiennaReed8 Indian friend made observation of people in India vs. U.S.  In India people will gladly talk about their income, but do not want to answer personal questions about family.  In the U.S. people will tell you all there family issues, but don't want to answer questions about income."
#
#     },
#
#     {
#
#         "id": "1523479486733332480",
#
#         "lang": "en",
#
#         "text": "Observation of $XAO \n\nASX All Ordinaries is about 100 points off pre-covid Feb 2020 levels of 7255. Currently 7,349. \n\nPretty much 2 years of gains gone from 12 month high of 7,956 and 10% down since Jan 2022\n\n\ud83e\uddd0 https://t.co/OeTRfQtXnW"
#
#     },
#
#     {
#
#         "id": "1523479444224024576",
#
#         "lang": "en",
#
#         "text": "@m3m3ntovivere Lol it\u2019s nothing serious. Just an observation"
#
#     },
#
#     {
#
#         "id": "1523479326703841280",
#
#         "lang": "en",
#
#         "text": "@RobNerl @PatCanAct @SebastianComedy Just an observation. His set had nothing to do with the racial makeup of the crowd.  Comics do a set. He actually commented during a overreaction about Florida never shutting down this isn't a rally. I've never been to an all white event before. Sorry just fucked me up"
#
#     },
#
#     {
#
#         "id": "1523479317312774144",
#
#         "lang": "en",
#
#         "text": "@JeremyTColes @theDoukai @ml_barnett @JamesSurowiecki @ATabarrok @mattyglesias But my initial comment was merely a sort of off the cuff observation about how wonky administration is and how its inevitably colored by popular perceptions."
#
#     },
#
#     {
#
#         "id": "1523479131953893376",
#
#         "lang": "en",
#
#         "text": "the terrible observation of Marco Verratti https://t.co/SjWEMa4YO2 \u26bd\ufe0f\u26bd\ufe0f  \ud83d\udcf2 Bet now via \u27f6 https://t.co/0I4IIflkwI \u221a https://t.co/MMCUOhrk3H"
#
#     },
#
#     {
#
#         "id": "1523479111645073408",
#
#         "lang": "en",
#
#         "text": "@gothtech_ @Sirethtv tours have been closed since covid i'm pretty sure. they have an \"observation deck\" where you can see it being made though"
#
#     },
#
#     {
#
#         "id": "1523479098563063808",
#
#         "lang": "en",
#
#         "text": "@MikeBelleville @mulletmilitia99 @EsthertheDog570 @KoonsKarl @JackPosobiec I'm not trying to make a political statement. I'm just making an observation. But continue on thinking I'm making a political statement."
#
#     },
#
#     {
#
#         "id": "1523478948671197184",
#
#         "lang": "en",
#
#         "text": "@uni_nanhee yep. based on observation, before when i was still running ny acc on private, all I can see were my moots but everything changed when I made it public"
#
#     },
#
#     {
#
#         "id": "1523478936553893888",
#
#         "lang": "en",
#
#         "text": "@sibi_tweetz Actually Chrisanghi\u2019s basic problems address cheytha Chrisanghi can be eradicated.\n\nIt\u2019s like Remo character derived from Ambi because \u201clove was denied\u201d in the movie Annyan.\n\nThis is my 1st observation about them."
#
#     },
#
#     {
#
#         "id": "1523478688192290816",
#
#         "lang": "en",
#
#         "text": "#EveshamWeather Observation @ 02:43 - Temp: 10.9\u00b0c, Wind: 0.0 gusting to 0.9 kph,  Pressure: 1026.8, Rain: 0.0mm/h now with 0.0mm today"
#
#     },
#
#     {
#
#         "id": "1523478672488865792",
#
#         "lang": "en",
#
#         "text": "@dalostboyz @cmhughesmd @shannonrwatts @ABCNews4 He believes he is being wise. 100 year old observation, btw."
#
#     },
#
#     {
#
#         "id": "1523478590763208704",
#
#         "lang": "en",
#
#         "text": "Interesting observation: gr 12 students asked to answer \u201cI wish my teachers knew/would\u2026\u201d and \u201cit annoys me when\u2026\u201d then they were asked to categorize and sort the feedback. They had the MOST to say about teaching practices/attitudes"
#
#     },
#
#     {
#
#         "id": "1523478370583216128",
#
#         "lang": "en",
#
#         "text": "Summit One An observation deck featuring glass elevators and \"levitation\" boxes One Vanderbilt supertall skyscraper in Midtown Manhattan NYC #Travel #Adventure Thrilling #Photography Sightseeing \n https://t.co/8TkRSOiNCk @Sea_Aras @CONTEMPRA_INN\ud83c\udf39"
#
#     },
#
#     {
#
#         "id": "1523478254467751936",
#
#         "lang": "en",
#
#         "text": "@JordiSens @AndrewBerkshire Thanks Sherlock for your insightful observation."
#
#     },
#
#     {
#
#         "id": "1523478244120416256",
#
#         "lang": "en",
#
#         "text": "@ZenaidaAsiatica @ICallBUllToo @craftymom35 @kimmyann1111 @ReignOfApril You\u2019re conflating morals and values with empirics and observation, which is foolish. You can prove that the earth isn\u2019t flat with math, science, and repeated testing. You can\u2019t really do that for things like \u201cstealing is bad\u201d unless you know someone/thing I don\u2019t."
#
#     },
#
#     {
#
#         "id": "1523478234980962304",
#
#         "lang": "en",
#
#         "text": "@AryasOf @monsieurmrsir From someone neutral on the religion question, my observation is this: Early Christianity and modern (Protestant) Christianity are progressivist semitic religions, but the Christianities of the middle ages (Ortho, Cath) revived the Aryan spirit under Christian aesthetics"
#
#     },
#
#     {
#
#         "id": "1523478111278755840",
#
#         "lang": "en",
#
# ...
#
#     },
#
#     {
#
#         "id": "1523485860632481792",
#
#         "lang": "en",
#
#         "text": "munching on a puffy easy passive income"
#
#     },
#
#     {
#
#         "id": "1523485848104476672",
#
#         "lang": "en",
#
#         "text": "@Lucy63595571 @phoenixicf https://t.co/HKnIHJzIMY\n\ud83e\udd96 The First Move To Earn App With Virtual Dinosaurs\nEarn while building healthy habits with the Dino\nVaried NFTs\nPassive Income Features\nApp Activation Code &amp; NFT Drop For Fair Launch Contributors\n\ud83d\ude80 Fair Launch Starts On May 9th\nhttps://t.co/e3mH9AspG0"
#
#     },
#
#     {
#
#         "id": "1523485847403724800",
#
#         "lang": "en",
#
#         "text": "Are the GST, Income Tax, etc taxes to be collected by Tamil Nadu state government instead of union government in union of India \ud83c\uddee\ud83c\uddf3???!!! @PMOIndia @rashtrapatibhvn @ANI @JoeBiden @mkstalin @Arunan22 @CTRavi_BJP @HMOIndia @IAF_MCC @news7tamil @the_hindu @PTI_News @BJP4TamilNadu https://t.co/AiwGS6axkk"
#
#     },
#
#     {
#
#         "id": "1523485846678036480",
#
#         "lang": "en",
#
#         "text": "\ud83c\udf89We are excited to announce an official partnership with @BABYOKX10000X, a collection born on April Fool's Day, April 1, 2022. #BNBchain #BSC\n\nNFT cards can be pledged to mine BABYOKD+Gamefi+ marketing income.\n\n\ud83d\udc49Check them here: https://t.co/plzYb9kUC5 https://t.co/BMcZ3YW7Yi"
#
#     },
#
#     {
#
#         "id": "1523485841586229248",
#
#         "lang": "en",
#
#         "text": "@RocketFreddie State. With penalties for animal abuse. Free health care, basic income, provided housing..."
#
#     },
#
#     {
#
#         "id": "1523485839837175808",
#
#         "lang": "en",
#
#         "text": "This guy has already made his money and he knows he can't convince parents to vaccinate their children after this..he is now worried about his passive income \"childhood immunisation\" getting affected, so he will admit more things like here after.. https://t.co/zuV3fnQY4I"
#
#     },
#
#     {
#
#         "id": "1523485835588366336",
#
#         "lang": "en",
#
#         "text": "@22Medic Still\n\nTf2 definetly is one of their big sources of income and they're letting it get flushed like a turd because they wanna make more money off of CS:Go n the other comp games they have"
#
#     },
#
#     {
#
#         "id": "1523485833612779521",
#
#         "lang": "en",
#
#         "text": "@Bscgemalerts FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/QhV0rzivhl"
#
#     },
#
#     {
#
#         "id": "1523485825060638720",
#
#         "lang": "en",
#
#         "text": "Here\u2019s the Stunning Amount of Passive Income You Can Make Staking Shiba\u00a0Inu https://t.co/5WwYRJHQxn"
#
#     },
#
#     {
#
#         "id": "1523485805393563648",
#
#         "lang": "en",
#
#         "text": "For anybody who likes to earn an income with a web based business it is advisable to look at the advice in this video https://t.co/XVmge08F3e https://t.co/l1ZOUe9YIw"
#
#     },
#
#     {
#
#         "id": "1523485797336621056",
#
#         "lang": "en",
#
#         "text": "@shibabetsgaming #DINOSTEP.APP\n\n\ud83e\udd96The First Move To Earn App With Virtual Dinosaurs\n\ud83d\udc5fEarn while building healthy habits with the Dino\n\u2728Varied NFTs\n\ud83d\udcb5 Passive Income Features\n\ud83d\udc8eApp Activation Code &amp; NFT Drop For Fair Launch Contributors\n\nFair Launch Starts On May 9th\n\nTG: https://t.co/1or9ND0jw2"
#
#     },
#
#     {
#
#         "id": "1523485791749500928",
#
#         "lang": "en",
#
#         "text": "@RepSwalwell @SusanSarandon Attacking the Goddess known as @SusanSarandon?\n\nThis sounds like you have a Temper Tantrum because you want Low &amp; Middle Class people in the Military and 6-Digit Dollar Income Earners to get Lower Taxes &amp; Millionaires &amp; Billionaires Tax Free, oh you are so #DumpsterChucked Eric.. https://t.co/LOYB0LZV7y"
#
#     },
#
#     {
#
#         "id": "1523485759407538176",
#
#         "lang": "en",
#
#         "text": "@neby_nebs @dottirofthor @brooks_wtf @BigDarkwah We just want every American to earn a livable income. If that requires higher education pay for it."
#
#     },
#
#     {
#
#         "id": "1523485751798759424",
#
#         "lang": "en",
#
#         "text": "Excellent point. It is critical to identify clearly your audience, e.g., middle-income women, independents, democrats, republican fence sitters, or radical right. \nEach audience might view \"steal\" differently. Make sure you validate that your message was understood. Engage them. https://t.co/G28H33ltq9"
#
#     },
#
#     {
#
#         "id": "1523485745029148675",
#
#         "lang": "en",
#
#         "text": "@circuit_eth FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/wUVFOTCj2W"
#
#     },
#
#     {
#
#         "id": "1523485741283950594",
#
#         "lang": "en",
#
#         "text": "Public housing is owned by the state (theoretically the people). Rent is capped at 30% of tenant\u2019s income. \nAccess to Housing is a basic right.\n\u201cSocial housing\u201d is a gap Band-Aid, not a solution.\nSee @vic_socialists for an actual public housing policy.\n#PeopleB4Profit\n#AusVotes"
#
#     },
#
#     {
#
#         "id": "1523485739417481216",
#
#         "lang": "en",
#
#         "text": "@GriffithAdelai6 https://t.co/HKnIHJzIMY\n\ud83e\udd96 The First Move To Earn App With Virtual Dinosaurs\nEarn while building healthy habits with the Dino\nVaried NFTs\nPassive Income Features\nApp Activation Code &amp; NFT Drop For Fair Launch Contributors\n\ud83d\ude80 Fair Launch Starts On May 9th\nhttps://t.co/e3mH9AspG0"
#
#     },
#
#     {
#
#         "id": "1523485717539680256",
#
#         "lang": "en",
#
#         "text": "@RobinJParker4 @CanadianChaos4 @monty_teaches @PamKeithFL @ZeldaBizarre Also, did you know certain antibiotics can render your birth control useless? For that and other reasons Plan B, which is not the abortion pill, needs to be as accessible as possible, especially in low income areas. It\u2019s sometimes given to rape victims for free. Always should be."
#
#     },
#
#     {
#
#         "id": "1523485693728546816",
#
#         "lang": "en",
#
#         "text": "@MarketRebels I want buying opportunities and my income is very stable. I guess that makes me a 1, or a happy 10?"
#
#     },
#
#     {
#
#         "id": "1523485684019101696",
#
#         "lang": "en",
#
#         "text": "neoliberal Australian electorate: \"yea!! Remember to vote!! Democracy Sausage!!\"\n\nThe only parties with a chance of winning:\n\"we are committed to driving the world into a mass extinction event, increasing income inequality, and just generally fucking shit up\""
#
#     },
#
#     {
#
#         "id": "1523485657615958017",
#
#         "lang": "en",
#
#         "text": "@DogeBlocky https://t.co/HKnIHJzIMY\n\ud83e\udd96 The First Move To Earn App With Virtual Dinosaurs\nEarn while building healthy habits with the Dino\nVaried NFTs\nPassive Income Features\nApp Activation Code &amp; NFT Drop For Fair Launch Contributors\n\ud83d\ude80 Fair Launch Starts On May 9th\nhttps://t.co/e3mH9AspG0"
#
#     },
#
#     {
#
#         "id": "1523485646618521603",
#
#         "lang": "en",
#
#         "text": "@BaseIncomeQuote @bootstrapsfilm The sun is about to set of a centuries old model.\ud83d\ude32\n\n1/ Get an education/skills\n2/ Take skills/quals to the marketplace \n3/ Gain employment \n4/ Derive an income \n5/ Sustain yourself &amp; family financially.  \n\nAre we psychologically ready.\ud83e\udd14\nAre there policies now to deal with this?"
#
#     },
#
#     {
#
#         "id": "1523485638288236546",
#
#         "lang": "en",
#
#         "text": "There is simply a large amount of insight on the web associated with generating income on line, listed here help and advice that you might want https://t.co/2GznTwqnCd https://t.co/7YNofWFngM"
#
#     },
#
#     {
#
#         "id": "1523485621385191424",
#
#         "lang": "en",
#
#         "text": "@Fosfolina @spdbt @Karl_Lauterbach Because millions of cannabis users have been unreasonably targeted for far too long by the law. There are other problems too of course, but ending discrimination against weed smokers, freeing up police resources and getting more tax income is right up there with them. Thank you!"
#
#     },
#
#     {
#
#         "id": "1523485612900188162",
#
#         "lang": "en",
#
#         "text": "@cryptojack FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/wOgxhlJ6Y4"
#
#     },
#
#     {
#
#         "id": "1523485601009659904",
#
#         "lang": "en",
#
#         "text": "@kevinbonham Is it true that IPSOS adjusts for income but not for the education level of respondents? Unlike Newspoll, which I understands adjusts for both?"
#
#     },
#
#     {
#
#         "id": "1523485595099566080",
#
#         "lang": "en",
#
#         "text": "Give up suffering shortage income employ all these dynamic tricks to produce more clients  https://t.co/8niGOb3OYB"
#
#     },
#
#     {
#
#         "id": "1523485585553338368",
#
#         "lang": "en",
#
#         "text": "@mwi2lcox @steveliesman haha... oh man, that is why CA is never worried about TX. No State income tax, exceeept..."
#
#     },
#
#     {
#
#         "id": "1523485580775989248",
#
#         "lang": "en",
#
#         "text": "@ltgrusselhonore @POTUS @VP @CDCgov @HHSGov @SpeakerPelosi @MSNBC @CNN @Newsweek @NPR From last week: \u201cIn March, the Medicines Patent Pool (MPP) had signed a license agreement with 35 generic drug makers to manufacture the generic version of Pfizer\u2019s oral COVID-19 treatment\u2026 in 95 low-and middle-income countries."
#
#     },
#
#     {
#
#         "id": "1523485570822905856",
#
#         "lang": "en",
#
#         "text": "@WhaleEverything FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/2wMgfkTHYN"
#
#     },
#
#     {
#
#         "id": "1523485535599480833",
#
#         "lang": "en",
#
#         "text": "@TamDZS @carlcyndi5 @TMfin78 @LauraRBelin Nope, you can look it up for yourself in the IRS data.\n\nhttps://t.co/pOJrgd2KO7"
#
#     },
#
#     {
#
#         "id": "1523485523196534786",
#
#         "lang": "en",
#
#         "text": "@FrankLuntz What about money on fixed income?"
#
#     },
#
#     {
#
#         "id": "1523485463402541056",
#
#         "lang": "en",
#
#         "text": "@elonmusk If you die, can I have 1% of twitter income?"
#
#     },
#
#     {
#
#         "id": "1523485436739424256",
#
#         "lang": "en",
#
#         "text": "Innodata Inc's quarterly revenue growth rate YoY of 26.10% ranked 1410 out of 5737 companies in our database. \n\nhttps://t.co/DxRNn2pAqh $INOD\n\n\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80 https://t.co/saXN8mZOKd"
#
#     },
#
#     {
#
#         "id": "1523485434902417409",
#
#         "lang": "en",
#
#         "text": "A popular investing strategy for long-term crypto investors, staking pools promise a regular income stream for the tokens staked with certain riders.  https://t.co/AuBfKAyLkD #TechNEWS"
#
#     },
#
#     {
#
#         "id": "1523485423921950720",
#
#         "lang": "en",
#
#         "text": "@CryptoNesiaReal @Astarter_Pad @MissIndahReal How does Astarter evaluate the investor's role in your project? How does Astarter deliver optimal returns for both projects and investors? Can I generate passive income with $Astarter ? If so, please share about mopr issue?"
#
#     },
#
#     {
#
#         "id": "1523485422407630849",
#
#         "lang": "en",
#
#         "text": "NEW MODEL for WORKING FROM HOME 2022 by #ONPASSIVE\nIT IS HAPPENING\u2757\ufe0f\n\n\ud83d\udc77\u2642\ud83d\udc77\u2640We do all the work! \n\ud83d\udcb0You get income!\nhttps://t.co/iT2vzH2gJd\n#ONPASSIVE #OFounders #earn #GoFounders #Business  #AI #ArtificialIntelligence #Technology  #Innovation #inittowinit #A... https://t.co/OneiMiT4DX"
#
#     },
#
#     {
#
#         "id": "1523485420541022215",
#
#         "lang": "en",
#
#         "text": "@JAGANTRS @KTRTRS Modi also created 100 unicorns .. \n\nKCR family also crossed unicorns income .."
#
#     },
#
#     {
#
#         "id": "1523485392640507904",
#
#         "lang": "en",
#
#         "text": "How tf does anyone make substantial income?!?!? I just wanna be able to buy a home for my family!!!! Fml!!!!"
#
#     },
#
#     {
#
#         "id": "1523485381395574788",
#
#         "lang": "en",
#
#         "text": "Can you use a HELOC for a portion if not all of your down payment on an SBA acquisition loan? The answer is YES!  The caveat is that the HELOC payments must be made by income other than the business you are purchasing. \n#SBA7a #SBAtwit"
#
#     },
#
#     {
#
#         "id": "1523485379965648896",
#
#         "lang": "en",
#
#         "text": "That is woefully insufficient for survival! #ontario needs to give people enough to meet their needs #onvote #income #fixedincome https://t.co/dD7aiIFB2x"
#
#     },
#
#     {
#
#         "id": "1523485365067079680",
#
#         "lang": "en",
#
#         "text": "@altcryptocom @AltcoinWorldcom FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/3SGGY32LTW"
#
#     },
#
#     {
#
#         "id": "1523485318309052417",
#
#         "lang": "en",
#
#         "text": "@CryptoGemsCom FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/DmBkFOyi2X"
#
#     },
#
#     {
#
#         "id": "1523485286595969025",
#
#         "lang": "en",
#
#         "text": "Beyond income: correlates of conspicuous and luxury consumption in\u00a0India https://t.co/vDd3CPzGm4"
#
#     },
#
#     {
#
#         "id": "1523485279415193600",
#
#         "lang": "en",
#
#         "text": "@WhaleEverything FARMINU\n\n\ud83d\udcb5 3% BUSD AUTO REWARDS\n \ud83d\uddbc NFT and P2E Oriented \n \ud83d\udcca Passive Income\n \ud83c\udf31 LP Locked, SC Renounced\n 0x4CD54b1f9AA38fcBF5B678b5797b03B652500473\n\n DEV DOXXED \n \ud83c\udf10Website: https://t.co/HkoRd3AbFL\n \ud83d\udcacTG: https://t.co/2lN18y8RNK @farminutoken\n @1goonrich \n @DelCrxpto\n@elonmusk https://t.co/1X49avYRzL"
#
#     },
#
#     {
#
#         "id": "1523485275967856640",
#
#         "lang": "en",
#
#         "text": "@rosae1307 @spunkyP81 @FoxNews Healthcare for all? Who\u2019s going to pay for it , if I\u2019m healthy and I never go to the doctor why should I pay half my income so someone who smokes drinks and eats junk food all day and has all kinds of health problems can be at the doctor once a week."
#
#     }
#
# ]

# %% [markdown]
# **Instruction 2.3**. To examine the number of tweets loaded from your data files, write your code to print out the number of tweets containes in three variables: ***k1_tweets, k2_tweets*** and ***k3_tweets***.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print out the number of tweets containes in three variables: 
k1_tweets, k2_tweets and k3_tweets
'''
#INSERT YOUR CODE HERE
print(len(k1_tweets))
print(len(k2_tweets))
print(len(k3_tweets))
# Out:
# 410
# 454
# 426

# %% [markdown]
# **Note**. When analysing tweets and text documents in general, an important analytics skill is to pre-process and filter the data into the form that one can start to apply analytics methods to extract knowledge.
#
# Tweets that are too short might not be useful for analysis. We define that tweets having less than 50 characters are short and should be remove.

# %% [markdown]
# **Instruction 2.4**. In this task, you need to filter all short tweets.
#
# 1. Write a function called `is_short_tweet` that takes a tweet as an input and return True if the text of the tweet has less than 50 characters and False otherwise. **(5 marks)**
#
# 2. Write your codes to remove all tweets that have less than 50 characters in variables ***k1_tweets***, ***k2_tweets*** and ***k3_tweets*** and store the results in the new variables ***k1_tweets_filtered***, ***k2_tweets_filtered*** and ***k3_tweets_filtered***, respectively. **(5 marks)**
#
# [**Total mark: 10**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
def is_short_tweet(tweet):
    '''
    Check if the text of "tweet" has less than 50 characters
    '''
    # INSERT YOUR CODE HERE
    for tw in tweet:
        if len(tw['text']) >= 50:
            print ("FALSE:: " + tw['text'][:50])
        else:                    
            print ("TRUE:: " + tw['text'])

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODES IN THIS CELL
'''
Write your codes to remove all tweets which have less than 50 characters in variables 
k1_tweets, k2_tweets and k3_tweets and store the results in the new variables 
k1_tweets_filtered, k2_tweets_filtered and k3_tweets_filtered respectively
'''
# INSERT YOUR CODE HERE
k1_tweets_filtered = [l['text'] for l in k1_tweets if len(l['text']) >= 50]

k2_tweets_filtered = [l['text'] for l in k2_tweets if len(l['text']) >= 50]

k3_tweets_filtered = [l['text'] for l in k3_tweets if len(l['text']) >= 50]


# these lines below print the number of tweets for each keyword before and after filtered.
print(len(k1_tweets), len(k1_tweets_filtered))
print(len(k2_tweets), len(k2_tweets_filtered))
print(len(k3_tweets), len(k3_tweets_filtered))
# Out:
# 410 387
# 454 414
# 426 419

# %% [markdown]
# **Instruction 2.5**. For each keyword, print out the number of tweets that have been removed.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
For each keyword, print out the number of tweets that have been removed.
'''
print(len(k1_tweets) - len(k1_tweets_filtered))

print(len(k2_tweets) - len(k2_tweets_filtered))

print(len(k3_tweets) - len(k3_tweets_filtered))
# Out:
# 23
# 40
# 7

# %% [markdown]
# **Instruction 2.6**. To examine what the tweets look like after being loaded from the data files and filtered, in the cell below write your code to print out the first **5** tweets for each keyword.
#
# You **must** use the variables ***k1_tweets_filtered, k2_tweets_filtered*** and ***k3_tweets_filtered*** which have stored the data after the filtering process for this task.
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print out the first 5 tweets for each keyword.
You must use the variables k1_tweets_filtered, k2_tweets_filtered and k3_tweets_filtered 
which have stored the data after the filtering process for this task.

Hint: Using tweet['text'] for tweet in k1_tweets_filtered
'''

print('The first 5 tweets for \"{}\":\n'.format(keywords[0]))
print(k1_tweets_filtered[0:6])

print('\nThe first 5 tweets for \"{}\":\n'.format(keywords[1]))
print(k2_tweets_filtered[0:6])


print('\nThe first 5 tweets for \"{}\":\n'.format(keywords[2]))
print(k3_tweets_filtered[0:6])
# Out:
# The first 5 tweets for "observation":
#
# ['just going over my schedule for the upcoming week \nmonday: final student teaching observation/evaluation \ntuesday: certification exam \nwednesday: department meeting\nthursday: certification exam\nfriday: last day of student teaching \nsaturday: graduation \nsunday: alcohol', "@phoenix909 @cryharderdem @KYSecState There is no MY side remember? The left vs right argument is just an observation. The left owns most media. Including fox. Though recently the right bought CNN, most of the proposed changes haven't gone into effect yet.", "Why do people have to be so damn stupid on this app? I don't care how well Pizza Hut is doing. I made an observation questioning how well Pizza Hut was doing based on the fact that 3 locations within a 60 mile radius closed within the last 2 years and got attacked for it. #Stupid", '@anttimatterr hmmm 🧐 incheresting observation here mr anttimatterr', 'Shaun Micallef made an interesting observation during the debacle.\n\nCameras zoomed in on Morrison making him appear imposing, cameras zoomed out from Albo making him seem insignificant. Subliminal, sneaky and typical dirty tricks from Nine Entertainment.\n\n#Sosomeh #LeadersDebate']
#
# The first 5 tweets for "needle":
#
# ['A nigga really just shot up dope right in front of the cash checcin spot. When somebody’s tried to open the door he was like my bad excuse me, Needle hanging out the arm and all, Then proceeded to finish that hit #GothamCity 🦇 🗽', '@CE_Coulter I took the JJ and regretted it the minute the needle came out. My wife pushed me due to my age. I told her I was not afraid of death. Faced it before. Did it to make her feel good.', '@BillKristol We need to move the needle. Protest anywhere at anytime to keep our rights', "@BeckyLynchWWE When 🐐🐐🐐 #BIGTIMEBECKS was CHAMP.. THE BELT actually MATTERED! #FACTS Who has the BELT now? Idk because we don't care enough to watch them! They aren't a MegaStar like #BIGTIMEBECKS  The 🐐🐐! The Needle Mover!!!", '@SarahNSMTG Reason # 123654323477 \nI still main pithing needle']
#
# The first 5 tweets for "income":
#
# ['Experts say it is time to #raise #wages so people can cope with the rising #inflation, or else a long-term #crisis will be in the offing https://t.co/nqNbLy5waY', 'Understanding staking pools: The pros and cons of staking cryptocurrency A popular investing strategy for long-term crypto investors, staking pools promise a regular income stream for the tokens staked with certain riders. https://t.co/aRqu5ZKNIr', '“against any form of exploitative labor” okay sooooo all forms of work are bad?? got it. \n\nALL WORK IS EXPLOITATIVE, YOU ARE USING YOUR BODY TO MAKE AN INCOME NO MATTER WHAT INDUSTRY YOU BELONG TO. https://t.co/ACtJc9Rwa9', "https://t.co/XZlfXDUJG3\n\nLIBERA - The World's First Triple Passive Income &amp; Hyper Deflationary token coming to Centralized Exchanges\n🔱158K% Fixed APY\n🔱520% BUSD APR from DEX\n🔱8% passive income from CEX\n\nFair Launch May 07 2pm UTC 👉 https://t.co/qEQ6SpvdnC", "@AngryKaren1 @kimtart @camilamama @drmsgandhi @Chapmans_Canada Another lie. My GF has been in Healthcare for 9 years. She was forced to get it or lose her livelihood, pension, source of income, everything she's worked for. She did not want it, along with most of her colleagues but they had no choice. It was forced on them."]

# %% [markdown]
# ### Part 2B: Constructing Term-by-Document Matrix
#
# As we have learned in our class, in text analytics and in general dealing with unstructured data, to start perform **computational** tasks such as computing the distance between two documents, we need to represent them in **numerical** formats. A popular technique we have learned is the bag-of-word representation and the term-by-document matrix, also known as the vector-space model.
#
# This part of the assignment will require you to construct the term-by-document matrix for the tweets stored in three variables ***k1_tweets_filtered***, ***k2_tweets_filtered*** and ***k3_tweets_filtered***.

# %% [markdown]
# **Note.** Tweets are often not neat as you might have seen from early tasks. As tweet such as this
# ```
# Happy shopping👗👚👠👜 (with Vivi and Irmalia at @infomog) — https://t.co/fUGO9Eex1r
# ```
# might contain non-ASCII characters, emoticon, punctuations, etc. Building a bag-of-word representation **without** pre-processing the data can be ineffective.
#
# The following function ***pre_process()*** has been designed to preprocess the data for you.

# %%
def remove_non_ascii(s): return "".join(i for i in s if ord(i)<128)
def pre_process(doc):
    """
    pre-processes a doc
      * Converts the tweet into lower case,
      * removes the URLs,
      * removes the punctuations
      * tokenizes the tweet
      * removes words less that 3 characters
    """
    
    doc = doc.lower()
    # getting rid of non ascii codes
    doc = remove_non_ascii(doc)
    
    # replacing URLs
    url_pattern = "http://[^\s]+|https://[^\s]+|www.[^\s]+|[^\s]+\.com|bit.ly/[^\s]+"
    doc = re.sub(url_pattern, 'url', doc) 

    # removing dollars and usernames and other unnecessary stuff
    userdoll_pattern = "\$[^\s]+|\@[^\s]+|\&[^\s]+|\*[^\s]+|[0-9][^\s]+|\~[^\s]+"
    doc = re.sub(userdoll_pattern, '', doc)
    
    
    # removing punctuation
    punctuation = r"\(|\)|#|\'|\"|-|:|\\|\/|!|\?|_|,|=|;|>|<|\.|\@"
    doc = re.sub(punctuation, ' ', doc)
    
    return [w for w in doc.split() if len(w) > 2]

# %% [markdown]
# **Note**. For example, the following code will display the first tweet stored in the variable ***k1_tweets_filtered*** (for the first keyword) before and after it has been pre-processed.

# %%
tweet_k1 = k1_tweets_filtered[0]['text']
tweet_k1_processed = pre_process(tweet_k1)

print(tweet_k1)
# tweet_k1_processed is now a list of words. 
# We use ' '.join() method to join the list to a string.
print(' '.join(tweet_k1_processed))

# %% [markdown]
# **Instruction 2.7**. Use the example above, write your code to display the **first** tweets stored in the variables ***k2_tweets_filtered*** and ***k2_tweets_filtered*** before and after they have been pre-processed using the function ***pre_process()*** supplied earlier.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Use the example above, write your code to display the first tweets stored in 
the variables k2_tweets_filtered and k3_tweets_filtered before and after they 
have been pre-processed using the function pre_process() supplied earlier.
'''

# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.8**. Write your code to pre-process and clean up all tweets stored in the variable ***k1_tweets_filtered***, ***k2_tweets_filtered*** and ***k3_tweets_filtered*** using the function ***pre_process()*** to result in new variables ***k1_tweets_processed***, ***k2_tweets_processed*** and ***k3_tweets_processed***.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to pre-process and clean up all tweets 
stored in the variable k1_tweets_filtered, k2_tweets_filtered and k3_tweets_filtered using the 
function pre_process() to result in new variables k1_tweets_processed, k2_tweets_processed 
and k3_tweets_processed.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.9**. Now, write your code to print out the **first 5 processed tweets** for each keyword *(the processed tweets are stored in **k1_tweets_processed**, **k2_tweets_processed** and **k3_tweets_processed**)*
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Now write your code to print out the first 5 processed tweets for each keyword.
Hint: Each tweet in tweets_processed is now a list of words, not a string. 
      To print a string, you might need to use ' '.join(tweet), 
      when tweet is a processed tweet

'''

print('The first 5 processed tweets for k1_tweets_processed:')
# INSERT YOUR CODE HERE



print('\nThe first 5 processed tweets for k2_tweets_processed:')
# INSERT YOUR CODE HERE



print('\nThe first 5 processed tweets for k3_tweets_processed:')
# INSERT YOUR CODE HERE

# %% [markdown]
# **Note**. The following function ***construct_termdoc()*** has been implemented to construct the term-by-document matrix from a corpus of text data. **You will need this function for subsequent task**.

# %%
def construct_termdoc(docs, vocab=[]):
    """
    Construct a term-by-document-matrix
    
    docs: corpus
    vocab: pre-defined vocabulary
           if not supplied it will be automatically induced from the data
    
    returns the term-by-document matrix and the vocabulary of the passed corpus
    """
    
    # vocab is not passed
    if vocab == []:
        vocab = set()
        termdoc_sparse = []

        for doc in docs:       
            # computes the frequencies of doc
            doc_sparse = Counter(doc)    
            termdoc_sparse.append(doc_sparse)
            
            # update the vocab
            vocab.update(doc_sparse.keys())  

        vocab = list(vocab)
        vocab.sort()
    
    else:
        termdoc_sparse = []        
        for doc in docs:
            termdoc_sparse.append(Counter(doc))
            

    n_docs = len(docs)
    n_vocab = len(vocab)
    termdoc_dense = np.zeros((n_docs, n_vocab), dtype=int)

    for j, doc_sparse in enumerate(termdoc_sparse):
        for term, freq in doc_sparse.items():
            try:
                termdoc_dense[j, vocab.index(term)] = freq
            except:
                pass
            
    return termdoc_dense, vocab

# %% [markdown]
# **Instruction 2.10 (D)**. In the function ***construct_termdoc()***, a function **set** is used. Learn what this function does and explain its role in the function ***construct_termdoc()***. Write a brief answer.
#
# [**Total mark: 2**]

# %%
# In the function construct_termdoc(), a function "set" is used. Learn what this function does 
# and explain its role in the function construct_termdoc().
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#
#

# %% [markdown]
# **Note**. Now suppose that we would like to construct a term-by-document matrix for tweets collected for the **first keyword only**. The following piece of codes will do this by computing the term-by-document matrix and the vocabulary for tweets stored in **k1_tweets_processed**, print them out and visualise the corresponding term-by-document matrix stored in the variable ***k1_termdoc***. The corresponding vocabulary dictionary computed from this data will also be stored in the variable ***k1_vocab***.

# %%
'''
compute the term-by-document matrix and the the dictionary from the collection of 
tweets collected for the first keyword
'''
k1_termdoc, k1_vocab = construct_termdoc(k1_tweets_processed)

# print out the term-by-document matrix
print(k1_termdoc)
# print out the first 5 vocabulary entries
print(' '.join(k1_vocab[0:5]))  # print out only the first 5 vocabulary entries

# visualise the term-by-document matrix
fig, ax = plt.subplots(figsize=(10, 5))
ax.imshow(k1_termdoc)
ax.set_xlabel('term (vocabulary)')
ax.set_ylabel('documents (tweets)')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[0]))

# %% [markdown]
# **Note**. Next, we would like to compute the pairwise distances between every two tweets. This will help us to see how similar tweets are. This is a computational task that would be *not* possible to do if we use the raw tweets.
#
# However, with the term-by-document matrix, each tweet now is vector and corresponds to a row in the term-by-document matrix. Hence, we can use the distance between vectors to compute the distance between tweets. This is also known as the **vector space model** in information retrieval literature.

# %% [markdown]
# **Instruction 2.11**. Your tasks are:
#
# 1. Define a function to compute and return the Euclidean distance between two vectors as we have learned from the class notes. **(2 marks)**
#
# 2. Define a function to compute and return the cosine distance between two vectors as we have learned from the class notes. **(2 marks)**
#
# 3. Construct a single function that returns two distance matrices ***euclidean_distance_matrix***, and ***cosine_distance_matrix***, whose elements (i,j) store the Eulidean distance and the cosine distance between tweets i-th and i-jth. **You will need this function for subsequent task**. **(2 marks)**
#
# **[Total mark: 6]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

def Euclidean_distance(x,y):
    '''
    Compute and return the Euclidean distance between two vectors x and y
    '''
    # INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
def cosine_distance(x,y):
    '''
    Compute and return the cosine distance between two vectors x and y
    '''
    # INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
The function takes the termdoc matrix as the input and computes variables called "euclidean_distance_matrix" 
and "cosine_distance_matrix", which are matrices whose elements (i,j) store the Eulidean distance 
and the cosine distance between tweet i-th and i-jth.

Hint: you should store the distance matrices in numpy arrays for easier implementation in subsequent tasks
'''

def compute_distance_matrices(termdoc):
    # INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.12**.
#
# 1. Now you need to compute the distance matrices for **k1_termdoc** and then visualise these distance matrices. **(2 marks)**
#
# 2. Explain why cosine distance is always in the range between 0 and 1. **(2 marks)**
#
# 3. (HD) Using a scatter plot demonstrate relationship between Euclidean distance and cosine distance. **(2 marks)**
#
# 4. (HD) Is there a relationship between Euclidean distance and cosine similarity? Explain. **(2 marks)**
#
#
# **[Total mark: 8]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the distance matrices for k1_termdoc using the function "compute_distance_matrices"
# INSERT YOUR CODE HERE

# Visualise the distance matrices for this keyword
# Hint: use imshow() and colorbar() functions
# INSERT YOUR CODE HERE

# %%
# Explain why cosine distance is always in the range between 0 and 1.
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#

# %%
# Using a scatter plot demonstrate relationship between Euclidean distance and cosine distance.
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# INSERT YOUR CODE HERE

# %%
# Is there a relationship between Euclidean distance and cosine similarity? Explain. 
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#

# %% [markdown]
# **Instruction 2.13**. Similar to the example above for the first keyword, your task is to write codes in the cell below to compute the term-by-document matrix and the vocabulary for tweets stored in ***k2_tweets_processed***, print out the first **5** vocabularies and visualise this term-by-document matrix.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to compute the term-by-document matrix and the vocabulary for tweets stored 
in k2_tweets_processed
'''
# INSERT YOUR CODE HERE

'''
Write your code print out the first 5 vocabularies 
'''
# INSERT YOUR CODE HERE


'''
Write your code to visualise the term-by-document matrix
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# ***Instruction 2.14***. Next, your task is to write codes in the cell below to calculate the pairwise distance matrix for tweets collected for **second** keyword. Store this distance matrix in the variable named ***k2_euclidean_distances*** and **visualise** this matrix.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the distance matrix for k1_termdoc using the function "compute_euclidean_distance_matrix"
# INSERT YOUR CODE HERE

# Visualise the distance matrix for this keyword
# Hint: use imshow() and colorbar() functions
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.15**. Similarly, your task is to write codes in the cell below to compute the term-by-document matrix and the vocabulary for tweets stored in ***k3_tweets_processed***, print out the first **5** vocabularies and visualise this term-by-document matrix.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to compute the term-by-document matrix and the vocabulary for tweets stored 
in k3_tweets_processed
'''
# INSERT YOUR CODE HERE


'''
Write your code print out the first 5 vocabularies 
'''
# INSERT YOUR CODE HERE


'''
Write your code to visualise the term-by-document matrix
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# ***Instruction 2.16***. Next, your task is to write codes in the cell below to calculate the pairwise distance matrix for tweets collected for **third** keyword. Store this distance matrix in the variable named ***k3_euclidean_distances*** and visualise this matrix.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the distance matrices for k1_termdoc using the function "compute_distance_matrices"
# INSERT YOUR CODE HERE

# Visualise the distance matrix for this keyword
# Hint: use imshow() and colorbar() functions
# INSERT YOUR CODE HERE

# %% [markdown]
# ***Instruction 2.17 (HD)***. Compare the ranges of the values for cosine and Euclidean distances. Explain why the ranges are different. Think about the best example to explain why cosine distance is more convenient than Euclidean distance for text analysis.
#
# [**Total mark: 2**]

# %%
# Compare the ranges of the values for cosine and Euclidean distances. 
# Explain why the ranges are different. Explain why cosine distance 
# is more convenient than Euclidean distance for text analysis.
#
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#

# %% [markdown]
# ### Part 2C: Data Clustering
#
# Thus far in this assignment, we have collected tweets for each keyword and analysed them seperately. We have constructed the term-by-document matrix for each collection of tweets seperately. A fundemantal and common task in data science, analytics, machine learning, science and engineering is **clustering**. This is also known as unsupervised learning or exploratory data analysis as we have learned in our classes.
#
# This part of this assignment will use the Kmeans algorithm learned in our classes to cluster the **entire** colllection of tweets collected for **all** keywords. To do so, we need to compute the **distance** between **any** two pair of tweets. This requires us to compute a **joint** term-by-document matrix for all tweets.
#
# The reason that we **cannot** use the individual term-by-document matrices computed earlier (e.g.,***k1_termdoc, k2_termdoc, k3_termdoc***) for this task is because they have different dictionary sizes. Hence, tweets collected for different keywords have been represented by vectors of different dimension.
#
# The following piece of codes will help you to inspect these dimensions.

# %%
print('Dimension of the term-by-document matrix for keyword \"{}\":'.format(keywords[0]))
print('{} x {}\n'.format(k1_termdoc.shape[0],k1_termdoc.shape[1]))

print('Dimension of the term-by-document matrix for keyword \"{}\":'.format(keywords[1]))
print('{} x {}\n'.format(k2_termdoc.shape[0],k2_termdoc.shape[1]))

print('Dimension of the term-by-document matrix for keyword \"{}\":'.format(keywords[2]))
print('{} x {}\n'.format(k3_termdoc.shape[0],k3_termdoc.shape[1]))

# %% [markdown]
# **Note**. First, we need to gather all tweets together into a new variable named **all_tweets_processed** using the piece of codes below.

# %%
all_tweets_processed = k1_tweets_processed + k2_tweets_processed + k3_tweets_processed

# %% [markdown]
# **Instruction 2.18**. Your task is to write codes in the cell below to compute the term-by-document matrix and the vocabulary for all tweets stored in ***all_tweets_processed***, print out the first 5 vocabularies and visualise this term-by-document matrix.
#
# [**Total marks: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to compute the term-by-document matrix and the vocabulary for all tweets stored 
in all_tweets_processed
'''

all_termdoc, all_vocab = # INSERT YOUR CODE HERE

'''
Write your code print out the first 5 vocabularies 
'''
# INSERT YOUR CODE HERE

'''
Write your code to visualise the term-by-document matrix
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.19**. Next, your task is to write codes in the cell below to calculate the pairwise distance matrix for all tweets collected. Store this distance matrix in the variable named ***all_euclidean_distances*** and visualise this matrix.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the Euclidean distance matrix using compute_euclidean_distance_matrix() function

all_euclidean_distances, all_cosine_distances = # INSERT YOUR CODE HERE

# Visualise the distance matrix for this keyword
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.20 (HD)**.
# 1. Your task is to produce a scatter plot of Euclidean vs cosine distance for all tweets. [**1 mark**]
# 2. Fit first and second order polynomials to the data in the scatter plot and overplot them. [**2 marks**]
# 3. Explain why the plotted curves do not go through the centre of the points cloud. Which visualisation technique would be better to use here? [**1 mark**]
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# 1. Your task is to produce a scatter plot of Euclidean vs cosine distance for all tweets.
# INSERT YOUR CODE HERE

# 2. Fit first and second order polynomials to the data in the scatter plot and overplot it. 
# INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#3. Explain why the plotted curves do not go through the centre of the points cloud.
#  Which visualisation technique would be better to use here?
# INSERT YOUR COMMENTS HERE
#

# %% [markdown]
# **Note**. Next, we use Kmeans algorithm to cluster all tweets stored in term-by-document matrix ***all_termdoc***. An important requirement for the Kmeans is the specification of the number of clusters which will be specified the variable **n_clusters**.
#
# The following piece of codes will initialise a ***kmeans*** object to be used for subsequent clustering task.

# %%
'''
Initialise a kmeans object  from scikit-lean package
'''
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, init='k-means++', n_init=5, max_iter=3000,
                verbose=True, tol=0.000001, random_state=123456)

# %% [markdown]
# **Instruction 2.21**. Your task is to use the variable ***kmeans*** to perform clustering on the data stored in the variable ***all_termdoc***.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

'''
Use the variable kmeans to perform clustering on the data stored in the variable all_termdoc
Hint: revise the practical session on Kmeans algorithm or check out the documentation from scikit-learn
for Kmeans algorithm.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.22**. Write your codes to print out the cluster centers.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to print out the cluster centers.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.23 (HD)**. Explain below why visualising the clusters here is hard to do in this case.
#
# [**Total mark: 2**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
# Explain below why visualising the clusters here is hard to do in this case.
# INSERT YOUR COMMENT HERE

# %% [markdown]
# **Instruction 2.24 (HD)**. Nevertheless, it is possible to visualise the structure of the cluster centres - surprisingly, using bar charts. Each vector component in the cluster centre vectors corresponds to a word in the dictionary. The value (amplitude) of the vector component for each particular word in the dictionary shows the strength of presence of a word in the cluster.
# In this task, you want to:
# 1. Plot bar charts for each of the three clusters, obtained from KMeans, where each bar chart has 20 strongest words sorted by their presence strength. [**2 marks**]
# 2. Explain the bar charts from the point of view of chosen keywords, English grammar and our text preprocessing routine. [**1 marks**]
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# 1. Plot bar charts for each of the three clusters, obtained from KMeans, 
# where each bar chart has 20 strongest words sorted by their presence strength.
# INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
# Explain the bar charts from the point of view of chosen keywords, English grammar 
# and our text preprocessing routine.
# INSERT YOUR COMMENT HERE
#

# %% [markdown]
# **Instruction 2.25**. Write your codes to print out the first **200** cluster labels assigned to the first 200 tweets.
#
# [**Total marks: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to print out the first **200** cluster labels assigned to the first 200 tweets.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.26**. Next, we would like to obtain the quality of our clustering results. Write your code to obtain the labels of tweets for each keyword and store the labels in three new variables ***k1_labels***, ***k2_labels*** and ***k3_labels***, respectively.
#
# **[Total marks: 2]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

'''
Write your code to obtain the labels of tweets for each keyword
and store the labels of the first keyword in ***k1_labels***, 
the labels of the second keyword in ***k2_labels*** and
the labels of the third keyword in ***k3_labels***.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.27 (D)**. We examine what is the proprotion of tweets from different keywords (or categories) appear in the **first** cluster. Remember that **0** is the label for the first cluster (**1** for the second and **2** for the third clusters). Your tasks are:
#
# 1. Write your code to obtain the list of tweet indices of each keyword that are assigned to the first cluster. **(1 marks)**
#
# 2. Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the first cluster. **(1 marks)**
#
# **[Total mark: 2]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to obtain the list of tweet indices of each keyword that are assigned to the first cluster.
Hint: you might want to use numpy.where function.
'''
# obtain the list of tweet indices of keyword k1 that are assigned to the first cluster
# means that to find tweet indices that have label 0 in k1_labels
k1_idx_label0 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k2 that are assigned to the first cluster
# means that to find tweet indices that have label 0 in k2_labels
k2_idx_label0 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k3 that are assigned to the first cluster
# means that to find tweet indices that have label 0 in k3_labels
k3_idx_label0 = # INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the first cluster.
Hint: you need to plot a bar chart with three bars, 
each bar represents the number of tweets of each keyword that are assigned to the first cluster.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.28 (D)**. Similarly, write your codes to compute the the proprotion of tweets from different keywords (or categories) appear in the **second** cluster and plot a bar chart visualise this information.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# obtain the list of tweet indices of keyword k1 that are assigned to the second cluster
# means that to find tweet indices that have label 1 in k1_labels
k1_idx_label1 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k2 that are assigned to the second cluster
# means that to find tweet indices that have label 1 in k2_labels
k2_idx_label1 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k3 that are assigned to the second cluster
# means that to find tweet indices that have label 1 in k3_labels
k3_idx_label1 = # INSERT YOUR CODE HERE

# Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the second cluster
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.29 (D)**. Similarly, write your codes to compute the the proprotion of tweets from different keywords (or categories) appear in the **third** cluster and plot a bar chart visualise this information.
#
# [**Total mark: 1**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# obtain the list of tweet indices of keyword k1 that are assigned to the third cluster
# means that to find tweet indices that have label 2 in k1_labels
k1_idx_label2 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k2 that are assigned to the third cluster
# means that to find tweet indices that have label 2 in k2_labels
k2_idx_label2 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k3 that are assigned to the third cluster
# means that to find tweet indices that have label 2 in k3_labels
k3_idx_label2 = # INSERT YOUR CODE HERE

# Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the third cluster
# INSERT YOUR CODE HERE

# %% [markdown]
# ### END OF ASSIGNMENT 2 NOTEBOOK
#
# ----
